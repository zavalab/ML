# %%
import torch
import vae_model 
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
from tqdm.notebook import tqdm
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "STIXGeneral",
    "text.latex.preamble": r"\usepackage[utf8]{inputenc}\usepackage{amsmath}",
    "figure.figsize": [12, 4],  # ancho, Largo  
    "xtick.labelsize": 12,  # tamaño ticks en eje x
    "ytick.labelsize": 12   # tamaño ticks en eje y
})

# %% [markdown]
# Generar puntos usados para el encoder (training set )

# %%
bounds = torch.tensor([[1 , 1 , 1 , 30] ,
                       [60, 60, 60, 50]],dtype = torch.float64)
num_initial_points = 5000
initial_points = vae_model.data_encoder_generation(bounds , num_initial_points=num_initial_points)
print('Number of points generated:', len(initial_points))
# initial_points
# Out:
# Number of points generated: 5000

# %% [markdown]
# Load Model and updated the weights of the model with the file already saved and optimized.

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = vae_model.VariationalAutoencoder(emb_dim=71, hidden_dim = 115 , 
                                latent_dim=7).to(device)
checkpoint = torch.load('VAE_Intensified.pth', map_location=device)
model.load_state_dict(checkpoint['model_state_dict'])
model.eval()
# Out:
# VariationalAutoencoder(
#   (feed1_emb): Embedding(60, 71)
#   (feed2_emb): Embedding(60, 71)
#   (stagesdw_emb): Embedding(60, 71)
#   (stagescol_emb): Embedding(21, 71)
#   (encoder_fc): Sequential(
#     (0): Linear(in_features=284, out_features=115, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Linear(in_features=115, out_features=57, bias=True)
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Linear(in_features=57, out_features=28, bias=True)
#   )
#   (fc_mu): Linear(in_features=28, out_features=7, bias=True)
#   (fc_logvar): Linear(in_features=28, out_features=7, bias=True)
#   (decoder): Sequential(
#     (0): Linear(in_features=7, out_features=28, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Linear(in_features=28, out_features=57, bias=True)
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Linear(in_features=57, out_features=115, bias=True)
#     (5): LeakyReLU(negative_slope=0.01)
#     (6): Linear(in_features=115, out_features=284, bias=True)
#   )
#   (feed1_out): Linear(in_features=71, out_features=60, bias=True)
#   (feed2_out): Linear(in_features=71, out_features=60, bias=True)
#   (stagesdw_out): Linear(in_features=71, out_features=60, bias=True)
#   (stagescol_out): Linear(in_features=71, out_features=21, bias=True)
# )

# %% [markdown]
# Test if initial data can be reconstructed with accuracy and get bound for Z dimension.

# %%
# Get bounds of continuous latent space
z , min_bounds , max_bounds = vae_model.get_z_dimension(initial_points, model)

# %% [markdown]
# ### Begin Bayesian Optimization algorithm

# %%
# Manipulated variables
#                       Re, S/F, Vr, F1, F2, NDWT, NCT 
bounds = torch.tensor([[2.0, 50 , 15 ,1 , 1 , 1, 30] ,
                       [5.0, 100, 100 , 50, 50, 50, 50]],dtype = torch.float64)
var_types = ['real', 'real', 'real', 'int', 'int', 'int', 'int']

# Get initial points
num_initial_points = 50
initial_points_BO = vae_model.population_generation(bounds, var_types , num_initial_points=num_initial_points)
print('Number of points generated:', len(initial_points_BO))
# Out:
# Number of points generated: 50

# %%
# Discrete variables, format must be changed to long or int type
continuos_initial_points = initial_points_BO[:, 0:3].numpy()
discrete_initial_points = torch.tensor(np.array(initial_points_BO[:, 3:]),dtype=torch.long)
converted_points = vae_model.transform_discrete(continuos_initial_points,
                             discrete_initial_points, model)

# %% [markdown]
# Sort data to avoid hugh differences between designs

# %%
initial_points_BO = initial_points_BO[initial_points_BO[:, -1].argsort(descending=False)]

# %% [markdown]
# Evaluate all points in Aspen

# %%
output_nodes = [r"\Data\Streams\DCM\Output\MOLEFRAC\MIXED\DICHL-01"]       
listofcomponents = ['METHA-01','DICHL-01','N:N-D-01']
Application = vae_model.AspenSimulation_MOBO(aspen_file_path="Caso estudio intensificado.bkp",
                        output_nodes=output_nodes, listofcomponents=listofcomponents)
Application.connect()
# Evaluate the function at these initial points
initial_evals = torch.tensor(np.array([Application.run_simulation(point) for point in initial_points_BO]), dtype=torch.float64)
mask = initial_evals[:, 1] > -999
initial_evals = initial_evals[mask]
initial_points_BO = initial_points_BO[mask]
converted_points = converted_points[mask]
print('Max function value O.F 1:', initial_evals[:,1].max().item())
print('Min function value O.F 1:', initial_evals[:,1].min().item())
print('Max function value O.F 2:', initial_evals[:,0].max().item())
print('Min function value O.F 2:', initial_evals[:,0].min().item())
# Close aspen simulation 
Application.close()
# Out:
# Max function value O.F 1: -299.0148560007147
# Min function value O.F 1: -364.65197837297313
# Max function value O.F 2: 0.999001034
# Min function value O.F 2: 0.619461837

# %% [markdown]
# Multi objective procedure -  B.O / Initialize Class to start optimization procedure

# %%
iterations = 1
for iter in tqdm(range(iterations)):
    filename = r'Intensified_MOBO_STD'
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    model = vae_model.VariationalAutoencoder(emb_dim=71, hidden_dim = 115 ,
                                             latent_dim=7).to(device)
    checkpoint = torch.load('VAE_Intensified.pth', map_location=device)
    model.load_state_dict(checkpoint['model_state_dict'])
    model.eval()

    # Create instance for Aspen    
    output_nodes = [r"\Data\Streams\DCM\Output\MOLEFRAC\MIXED\DICHL-01"]       
    listofcomponents = ['METHA-01','DICHL-01','N:N-D-01']
    Application = vae_model.AspenSimulation_MOBO(aspen_file_path="Caso estudio intensificado.bkp",
                            output_nodes=output_nodes, 
                            listofcomponents=listofcomponents)

    all_points = converted_points
    all_objectives = initial_evals[:]
    var_names = ['reflujo', 'solvente', 'vapor' , 
                 'z1', 'z2', 'z3', 'z4', 'z5', 'z6', 'z7' ]
    obj_names = ['pureza', 'FEDI']

    z_train = z
    n_evals = 500
    latent_dim = 7
    bounds = torch.tensor([[2.0,50 ,50, min_bounds[0], min_bounds[1] , min_bounds[2], min_bounds[3], min_bounds[4], min_bounds[5], min_bounds[6]] ,
                           [5.0,100,60, max_bounds[0], max_bounds[1] , max_bounds[2], max_bounds[3], max_bounds[4], max_bounds[5], max_bounds[6]]],dtype = torch.float64)
    MOBO= vae_model.MultiObjectiveBayesianOpt( X_init = all_points , Y_init = initial_evals, 
                            bounds = bounds,  model_enddec = model,  
                            obj_names = obj_names,  latent_dim = latent_dim ,
                            n_evals = n_evals,  method='std' ,  Aspen_Application = Application  )
    MOBO.run_optimization()     
    filename = filename + str(iter) + '.csv'
    MOBO.save_data(file = filename)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Start optimization process
# number of functions evaluations: 31 number of iterations: 1
# number of functions evaluations: 33 number of iterations: 2
# number of functions evaluations: 36 number of iterations: 3
# number of functions evaluations: 42 number of iterations: 4
# number of functions evaluations: 44 number of iterations: 5
# number of functions evaluations: 48 number of iterations: 6
# number of functions evaluations: 51 number of iterations: 7
# number of functions evaluations: 53 number of iterations: 8
# number of functions evaluations: 58 number of iterations: 9
# number of functions evaluations: 62 number of iterations: 10
# number of functions evaluations: 67 number of iterations: 11
# number of functions evaluations: 68 number of iterations: 12
# number of functions evaluations: 72 number of iterations: 13
# number of functions evaluations: 73 number of iterations: 14
# number of functions evaluations: 80 number of iterations: 15
# number of functions evaluations: 84 number of iterations: 16
# number of functions evaluations: 85 number of iterations: 17
# number of functions evaluations: 88 number of iterations: 18
# number of functions evaluations: 90 number of iterations: 19
# number of functions evaluations: 93 number of iterations: 20
# All the proposed points were unfeasible. Re-sampling with more points…
# number of functions evaluations: 95 number of iterations: 21
# number of functions evaluations: 97 number of iterations: 22
# number of functions evaluations: 100 number of iterations: 23
# number of functions evaluations: 105 number of iterations: 24
# number of functions evaluations: 109 number of iterations: 25
# number of functions evaluations: 115 number of iterations: 26
# number of functions evaluations: 118 number of iterations: 27
# number of functions evaluations: 123 number of iterations: 28
# number of functions evaluations: 126 number of iterations: 29
# number of functions evaluations: 127 number of iterations: 30
# number of functions evaluations: 132 number of iterations: 31
# number of functions evaluations: 136 number of iterations: 32
# number of functions evaluations: 137 number of iterations: 33
# number of functions evaluations: 141 number of iterations: 34
# number of functions evaluations: 144 number of iterations: 35
# number of functions evaluations: 147 number of iterations: 36
# number of functions evaluations: 152 number of iterations: 37
# number of functions evaluations: 159 number of iterations: 38
# number of functions evaluations: 164 number of iterations: 39
# number of functions evaluations: 168 number of iterations: 40
# number of functions evaluations: 170 number of iterations: 41
# number of functions evaluations: 175 number of iterations: 42
# number of functions evaluations: 180 number of iterations: 43
# number of functions evaluations: 181 number of iterations: 44
# number of functions evaluations: 184 number of iterations: 45
# number of functions evaluations: 188 number of iterations: 46
# number of functions evaluations: 191 number of iterations: 47
# number of functions evaluations: 192 number of iterations: 48
# number of functions evaluations: 195 number of iterations: 49
# number of functions evaluations: 201 number of iterations: 50
# number of functions evaluations: 203 number of iterations: 51
# number of functions evaluations: 210 number of iterations: 52
# number of functions evaluations: 216 number of iterations: 53
# number of functions evaluations: 218 number of iterations: 54
# number of functions evaluations: 221 number of iterations: 55
# number of functions evaluations: 226 number of iterations: 56
# number of functions evaluations: 227 number of iterations: 57
# number of functions evaluations: 229 number of iterations: 58
# number of functions evaluations: 234 number of iterations: 59
# number of functions evaluations: 238 number of iterations: 60
# number of functions evaluations: 242 number of iterations: 61
# number of functions evaluations: 245 number of iterations: 62
# number of functions evaluations: 247 number of iterations: 63
# number of functions evaluations: 248 number of iterations: 64
# number of functions evaluations: 253 number of iterations: 65
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    model = vae_model.VariationalAutoencoder(emb_dim=71, hidden_dim = 115 ,
                                             latent_dim=7).to(device)
    checkpoint = torch.load('VAE_Intensified.pth', map_location=device)
    model.load_state_dict(checkpoint['model_state_dict'])
    model.eval()

    # Create instance for Aspen    
    output_nodes = [r"\Data\Streams\DCM\Output\MOLEFRAC\MIXED\DICHL-01"]       
    listofcomponents = ['METHA-01','DICHL-01','N:N-D-01']
    Application = vae_model.AspenSimulation_MOBO(aspen_file_path="Caso estudio intensificado.bkp",
                            output_nodes=output_nodes, 
                            listofcomponents=listofcomponents)

    all_points = converted_points
    all_objectives = initial_evals[:]
    var_names = ['reflujo', 'solvente', 'vapor' , 
                 'z1', 'z2', 'z3', 'z4', 'z5', 'z6', 'z7' ]
    obj_names = ['pureza', 'FEDI']

    z_train = z
    n_evals = 500
    latent_dim = 7
    bounds = torch.tensor([[2.0,50 ,50, min_bounds[0], min_bounds[1] , min_bounds[2], min_bounds[3], min_bounds[4], min_bounds[5], min_bounds[6]] ,
                           [5.0,100,60, max_bounds[0], max_bounds[1] , max_bounds[2], max_bounds[3], max_bounds[4], max_bounds[5], max_bounds[6]]],dtype = torch.float64)
    MOBO= vae_model.MultiObjectiveBayesianOpt( X_init = all_points , Y_init = initial_evals, 
                            bounds = bounds,  model_enddec = model,  
                            obj_names = obj_names,  latent_dim = latent_dim ,
                            n_evals = n_evals,  method='std' ,  Aspen_Application = Application  )
    MOBO.run_optimization()     
    filename = filename + str(iter) + '.csv'
    MOBO.save_data(file = filename)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Start optimization process
# number of functions evaluations: 31 number of iterations: 1
# number of functions evaluations: 33 number of iterations: 2
# number of functions evaluations: 36 number of iterations: 3
# number of functions evaluations: 42 number of iterations: 4
# number of functions evaluations: 44 number of iterations: 5
# number of functions evaluations: 48 number of iterations: 6
# number of functions evaluations: 51 number of iterations: 7
# number of functions evaluations: 53 number of iterations: 8
# number of functions evaluations: 58 number of iterations: 9
# number of functions evaluations: 62 number of iterations: 10
# number of functions evaluations: 67 number of iterations: 11
# number of functions evaluations: 68 number of iterations: 12
# number of functions evaluations: 72 number of iterations: 13
# number of functions evaluations: 73 number of iterations: 14
# number of functions evaluations: 80 number of iterations: 15
# number of functions evaluations: 84 number of iterations: 16
# number of functions evaluations: 85 number of iterations: 17
# number of functions evaluations: 88 number of iterations: 18
# number of functions evaluations: 90 number of iterations: 19
# number of functions evaluations: 93 number of iterations: 20
# All the proposed points were unfeasible. Re-sampling with more points…
# number of functions evaluations: 95 number of iterations: 21
# number of functions evaluations: 97 number of iterations: 22
# number of functions evaluations: 100 number of iterations: 23
# number of functions evaluations: 105 number of iterations: 24
# number of functions evaluations: 109 number of iterations: 25
# number of functions evaluations: 115 number of iterations: 26
# number of functions evaluations: 118 number of iterations: 27
# number of functions evaluations: 35 number of iterations: 2
# number of functions evaluations: 36 number of iterations: 3
# number of functions evaluations: 41 number of iterations: 4
# number of functions evaluations: 42 number of iterations: 5
# number of functions evaluations: 47 number of iterations: 6
# number of functions evaluations: 48 number of iterations: 7
# number of functions evaluations: 50 number of iterations: 8
# number of functions evaluations: 56 number of iterations: 9
# number of functions evaluations: 63 number of iterations: 10
# number of functions evaluations: 65 number of iterations: 11
# number of functions evaluations: 69 number of iterations: 12
# number of functions evaluations: 74 number of iterations: 13
# number of functions evaluations: 87 number of iterations: 14
# number of functions evaluations: 89 number of iterations: 15
# number of functions evaluations: 92 number of iterations: 16
# number of functions evaluations: 97 number of iterations: 17
# number of functions evaluations: 106 number of iterations: 18
# number of functions evaluations: 108 number of iterations: 19
# number of functions evaluations: 111 number of iterations: 20
# number of functions evaluations: 118 number of iterations: 21
# number of functions evaluations: 125 number of iterations: 22
# number of functions evaluations: 130 number of iterations: 23
# number of functions evaluations: 136 number of iterations: 24
# number of functions evaluations: 144 number of iterations: 25
# number of functions evaluations: 152 number of iterations: 26
# number of functions evaluations: 160 number of iterations: 27
# number of functions evaluations: 163 number of iterations: 28
# number of functions evaluations: 170 number of iterations: 29
# number of functions evaluations: 173 number of iterations: 30
# number of functions evaluations: 181 number of iterations: 31
# number of functions evaluations: 187 number of iterations: 32
# number of functions evaluations: 191 number of iterations: 33
# number of functions evaluations: 199 number of iterations: 34
# number of functions evaluations: 205 number of iterations: 35
# number of functions evaluations: 211 number of iterations: 36
# number of functions evaluations: 220 number of iterations: 37
# number of functions evaluations: 229 number of iterations: 38
# number of functions evaluations: 232 number of iterations: 39
# number of functions evaluations: 243 number of iterations: 40
# number of functions evaluations: 249 number of iterations: 41
# number of functions evaluations: 255 number of iterations: 42
# number of functions evaluations: 259 number of iterations: 43
# number of functions evaluations: 264 number of iterations: 44
# number of functions evaluations: 268 number of iterations: 45
# number of functions evaluations: 275 number of iterations: 46
# number of functions evaluations: 277 number of iterations: 47
# number of functions evaluations: 283 number of iterations: 48
# number of functions evaluations: 290 number of iterations: 49
# number of functions evaluations: 299 number of iterations: 50
# number of functions evaluations: 305 number of iterations: 51
# number of functions evaluations: 315 number of iterations: 52
# number of functions evaluations: 322 number of iterations: 53
# number of functions evaluations: 326 number of iterations: 54
# number of functions evaluations: 329 number of iterations: 55
# number of functions evaluations: 333 number of iterations: 56
# number of functions evaluations: 339 number of iterations: 57
# number of functions evaluations: 343 number of iterations: 58
# number of functions evaluations: 351 number of iterations: 59
# number of functions evaluations: 358 number of iterations: 60
# number of functions evaluations: 364 number of iterations: 61
# number of functions evaluations: 372 number of iterations: 62
# number of functions evaluations: 376 number of iterations: 63
# number of functions evaluations: 380 number of iterations: 64
# number of functions evaluations: 388 number of iterations: 65
# number of functions evaluations: 395 number of iterations: 66
# number of functions evaluations: 403 number of iterations: 67
# number of functions evaluations: 406 number of iterations: 68
# number of functions evaluations: 412 number of iterations: 69
# number of functions evaluations: 417 number of iterations: 70
# number of functions evaluations: 420 number of iterations: 71
# number of functions evaluations: 429 number of iterations: 72
# number of functions evaluations: 434 number of iterations: 73
# number of functions evaluations: 440 number of iterations: 74
# number of functions evaluations: 444 number of iterations: 75
# number of functions evaluations: 452 number of iterations: 76
# number of functions evaluations: 456 number of iterations: 77
# number of functions evaluations: 463 number of iterations: 78
# number of functions evaluations: 472 number of iterations: 79
# number of functions evaluations: 479 number of iterations: 80
# number of functions evaluations: 489 number of iterations: 81
# number of functions evaluations: 498 number of iterations: 82
# number of functions evaluations: 502 number of iterations: 83
# Start optimization process
# number of functions evaluations: 33 number of iterations: 1
# number of functions evaluations: 37 number of iterations: 2
# number of functions evaluations: 39 number of iterations: 3
# number of functions evaluations: 40 number of iterations: 4
# number of functions evaluations: 45 number of iterations: 5
# number of functions evaluations: 46 number of iterations: 6
# number of functions evaluations: 51 number of iterations: 7
# number of functions evaluations: 52 number of iterations: 8
# number of functions evaluations: 53 number of iterations: 9
# number of functions evaluations: 54 number of iterations: 10
# number of functions evaluations: 57 number of iterations: 11
# number of functions evaluations: 60 number of iterations: 12
# number of functions evaluations: 64 number of iterations: 13
# number of functions evaluations: 66 number of iterations: 14
# number of functions evaluations: 67 number of iterations: 15
# number of functions evaluations: 70 number of iterations: 16
# number of functions evaluations: 73 number of iterations: 17
# number of functions evaluations: 74 number of iterations: 18
# number of functions evaluations: 77 number of iterations: 19
# number of functions evaluations: 79 number of iterations: 20
# number of functions evaluations: 82 number of iterations: 21
# number of functions evaluations: 86 number of iterations: 22
# number of functions evaluations: 89 number of iterations: 23
# number of functions evaluations: 91 number of iterations: 24
# number of functions evaluations: 93 number of iterations: 25
# number of functions evaluations: 96 number of iterations: 26
# number of functions evaluations: 99 number of iterations: 27
# number of functions evaluations: 102 number of iterations: 28
# number of functions evaluations: 105 number of iterations: 29
# number of functions evaluations: 107 number of iterations: 30
# number of functions evaluations: 110 number of iterations: 31
# number of functions evaluations: 112 number of iterations: 32
# number of functions evaluations: 114 number of iterations: 33
# number of functions evaluations: 115 number of iterations: 34
# number of functions evaluations: 118 number of iterations: 35
# number of functions evaluations: 122 number of iterations: 36
# number of functions evaluations: 128 number of iterations: 37
# number of functions evaluations: 131 number of iterations: 38
# number of functions evaluations: 134 number of iterations: 39
# number of functions evaluations: 139 number of iterations: 40
# number of functions evaluations: 147 number of iterations: 41
# number of functions evaluations: 150 number of iterations: 42
# number of functions evaluations: 156 number of iterations: 43
# number of functions evaluations: 160 number of iterations: 44
# number of functions evaluations: 166 number of iterations: 45
# number of functions evaluations: 172 number of iterations: 46
# number of functions evaluations: 176 number of iterations: 47
# number of functions evaluations: 182 number of iterations: 48
# number of functions evaluations: 187 number of iterations: 49
# number of functions evaluations: 195 number of iterations: 50
# number of functions evaluations: 200 number of iterations: 51
# number of functions evaluations: 206 number of iterations: 52
# number of functions evaluations: 212 number of iterations: 53
# number of functions evaluations: 214 number of iterations: 54
# number of functions evaluations: 218 number of iterations: 55
# number of functions evaluations: 222 number of iterations: 56
# number of functions evaluations: 226 number of iterations: 57
# number of functions evaluations: 229 number of iterations: 58
# number of functions evaluations: 235 number of iterations: 59
# number of functions evaluations: 238 number of iterations: 60
# number of functions evaluations: 242 number of iterations: 61
# number of functions evaluations: 246 number of iterations: 62
# number of functions evaluations: 250 number of iterations: 63
# number of functions evaluations: 258 number of iterations: 64
# number of functions evaluations: 264 number of iterations: 65
# number of functions evaluations: 266 number of iterations: 66
# number of functions evaluations: 271 number of iterations: 67
# number of functions evaluations: 276 number of iterations: 68
# number of functions evaluations: 279 number of iterations: 69
# number of functions evaluations: 284 number of iterations: 70
# number of functions evaluations: 288 number of iterations: 71
# number of functions evaluations: 292 number of iterations: 72
# number of functions evaluations: 299 number of iterations: 73
# number of functions evaluations: 304 number of iterations: 74
# number of functions evaluations: 312 number of iterations: 75
# number of functions evaluations: 317 number of iterations: 76
# number of functions evaluations: 322 number of iterations: 77
# number of functions evaluations: 325 number of iterations: 78
# number of functions evaluations: 334 number of iterations: 79
# number of functions evaluations: 340 number of iterations: 80
# number of functions evaluations: 348 number of iterations: 81
# number of functions evaluations: 358 number of iterations: 82
# number of functions evaluations: 365 number of iterations: 83
# number of functions evaluations: 371 number of iterations: 84
# number of functions evaluations: 377 number of iterations: 85
# number of functions evaluations: 381 number of iterations: 86
# number of functions evaluations: 387 number of iterations: 87
# number of functions evaluations: 390 number of iterations: 88
# number of functions evaluations: 397 number of iterations: 89
# number of functions evaluations: 404 number of iterations: 90
# number of functions evaluations: 410 number of iterations: 91
# number of functions evaluations: 417 number of iterations: 92
# number of functions evaluations: 420 number of iterations: 93
# number of functions evaluations: 426 number of iterations: 94
# number of functions evaluations: 429 number of iterations: 95
# number of functions evaluations: 436 number of iterations: 96
# number of functions evaluations: 446 number of iterations: 97
# number of functions evaluations: 451 number of iterations: 98
# number of functions evaluations: 452 number of iterations: 99
# number of functions evaluations: 457 number of iterations: 100
# number of functions evaluations: 462 number of iterations: 101
# number of functions evaluations: 468 number of iterations: 102
# number of functions evaluations: 471 number of iterations: 103
# number of functions evaluations: 475 number of iterations: 104
# number of functions evaluations: 479 number of iterations: 105
# number of functions evaluations: 483 number of iterations: 106
# number of functions evaluations: 490 number of iterations: 107
# number of functions evaluations: 493 number of iterations: 108
# number of functions evaluations: 498 number of iterations: 109
# number of functions evaluations: 502 number of iterations: 110
# Start optimization process
# number of functions evaluations: 32 number of iterations: 1
# number of functions evaluations: 36 number of iterations: 2
# number of functions evaluations: 39 number of iterations: 3
# number of functions evaluations: 40 number of iterations: 4
# number of functions evaluations: 42 number of iterations: 5
# number of functions evaluations: 43 number of iterations: 6
# number of functions evaluations: 45 number of iterations: 7
# number of functions evaluations: 50 number of iterations: 8
# number of functions evaluations: 52 number of iterations: 9
# number of functions evaluations: 56 number of iterations: 10
# number of functions evaluations: 58 number of iterations: 11
# number of functions evaluations: 63 number of iterations: 12
# number of functions evaluations: 66 number of iterations: 13
# number of functions evaluations: 71 number of iterations: 14
# number of functions evaluations: 74 number of iterations: 15
# number of functions evaluations: 75 number of iterations: 16
# number of functions evaluations: 82 number of iterations: 17
# number of functions evaluations: 86 number of iterations: 18
# number of functions evaluations: 89 number of iterations: 19
# number of functions evaluations: 98 number of iterations: 20
# number of functions evaluations: 102 number of iterations: 21
# number of functions evaluations: 110 number of iterations: 22
# number of functions evaluations: 115 number of iterations: 23
# number of functions evaluations: 119 number of iterations: 24
# number of functions evaluations: 132 number of iterations: 25
# number of functions evaluations: 137 number of iterations: 26
# number of functions evaluations: 142 number of iterations: 27
# number of functions evaluations: 146 number of iterations: 28
# number of functions evaluations: 153 number of iterations: 29
# number of functions evaluations: 159 number of iterations: 30
# number of functions evaluations: 164 number of iterations: 31
# number of functions evaluations: 165 number of iterations: 32
# number of functions evaluations: 171 number of iterations: 33
# number of functions evaluations: 172 number of iterations: 34
# number of functions evaluations: 175 number of iterations: 35
# number of functions evaluations: 178 number of iterations: 36
# number of functions evaluations: 184 number of iterations: 37
# number of functions evaluations: 187 number of iterations: 38
# number of functions evaluations: 193 number of iterations: 39
# number of functions evaluations: 197 number of iterations: 40
# number of functions evaluations: 203 number of iterations: 41
# number of functions evaluations: 205 number of iterations: 42
# number of functions evaluations: 207 number of iterations: 43
# All the proposed points were unfeasible. Re-sampling with more points…
# number of functions evaluations: 211 number of iterations: 44
# number of functions evaluations: 215 number of iterations: 45
# number of functions evaluations: 222 number of iterations: 46
# number of functions evaluations: 225 number of iterations: 47
# number of functions evaluations: 228 number of iterations: 48
# number of functions evaluations: 234 number of iterations: 49
# number of functions evaluations: 236 number of iterations: 50
# number of functions evaluations: 239 number of iterations: 51
# number of functions evaluations: 240 number of iterations: 52
# number of functions evaluations: 244 number of iterations: 53
# number of functions evaluations: 247 number of iterations: 54
# All the proposed points were unfeasible. Re-sampling with more points…
# number of functions evaluations: 251 number of iterations: 55
# number of functions evaluations: 255 number of iterations: 56
# number of functions evaluations: 259 number of iterations: 57
# number of functions evaluations: 261 number of iterations: 58
# number of functions evaluations: 265 number of iterations: 59
# number of functions evaluations: 269 number of iterations: 60
# number of functions evaluations: 271 number of iterations: 61
# number of functions evaluations: 273 number of iterations: 62
# number of functions evaluations: 274 number of iterations: 63
# number of functions evaluations: 277 number of iterations: 64
# number of functions evaluations: 280 number of iterations: 65
# number of functions evaluations: 281 number of iterations: 66
# number of functions evaluations: 286 number of iterations: 67
# number of functions evaluations: 290 number of iterations: 68
# number of functions evaluations: 295 number of iterations: 69
# number of functions evaluations: 299 number of iterations: 70
# number of functions evaluations: 303 number of iterations: 71
# number of functions evaluations: 307 number of iterations: 72
# number of functions evaluations: 310 number of iterations: 73
# number of functions evaluations: 312 number of iterations: 74
# number of functions evaluations: 313 number of iterations: 75
# number of functions evaluations: 317 number of iterations: 76
# number of functions evaluations: 320 number of iterations: 77
# number of functions evaluations: 327 number of iterations: 78
# number of functions evaluations: 332 number of iterations: 79
# number of functions evaluations: 341 number of iterations: 80
# number of functions evaluations: 345 number of iterations: 81
# number of functions evaluations: 352 number of iterations: 82
# number of functions evaluations: 354 number of iterations: 83
# number of functions evaluations: 359 number of iterations: 84
# number of functions evaluations: 363 number of iterations: 85
# number of functions evaluations: 369 number of iterations: 86
# number of functions evaluations: 376 number of iterations: 87
# number of functions evaluations: 382 number of iterations: 88
# number of functions evaluations: 386 number of iterations: 89
# number of functions evaluations: 395 number of iterations: 90
# number of functions evaluations: 400 number of iterations: 91
# number of functions evaluations: 405 number of iterations: 92
# number of functions evaluations: 411 number of iterations: 93
# number of functions evaluations: 414 number of iterations: 94
# number of functions evaluations: 418 number of iterations: 95
# number of functions evaluations: 427 number of iterations: 96
# number of functions evaluations: 428 number of iterations: 97
# number of functions evaluations: 433 number of iterations: 98
# number of functions evaluations: 437 number of iterations: 99
# number of functions evaluations: 439 number of iterations: 100
# number of functions evaluations: 441 number of iterations: 101
# number of functions evaluations: 447 number of iterations: 102
# number of functions evaluations: 448 number of iterations: 103
# number of functions evaluations: 453 number of iterations: 104
# number of functions evaluations: 458 number of iterations: 105
# number of functions evaluations: 466 number of iterations: 106
# number of functions evaluations: 471 number of iterations: 107
# number of functions evaluations: 474 number of iterations: 108
# number of functions evaluations: 478 number of iterations: 109
# number of functions evaluations: 482 number of iterations: 110
# number of functions evaluations: 486 number of iterations: 111
# number of functions evaluations: 491 number of iterations: 112
# number of functions evaluations: 493 number of iterations: 113
# number of functions evaluations: 497 number of iterations: 114
# number of functions evaluations: 502 number of iterations: 115

# %%
import vae_model
file_df1  = "pareto_front_tracking.csv"
file_df2  = "data_front_tracking.csv"
iterations_sorted =  np.array([1, 11, 21, 31, 41, 61])
vae_model.plot_pareto_front_tracking(file_df1, file_df2 ,
                                      z, iterations_sorted)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # RUN WITH GENETIC ALGORITM

# %%
iterations = 5
# Open Aspen
aspen_file_path1 = "Caso estudio intensificado.bkp"

for iter in tqdm(range(iterations)):
    aspen1 = vae_model.aspen_files(aspen_file_path1)
    # Estar problem
    problem = vae_model.Intensified(aspen1)
    vae_model.run_NSGAII(problem= problem, aspen1=aspen1,
                        aspen_file_path1 = aspen_file_path1,
                        file = r'Intensified_NSGAII', iteration = iter )
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]

# %% [markdown]
# Save data for further analysis

# %%
import vae_model
filename_nsga = r"Intensified_NSGAII"
filename_bo = r"Intensified_MOBO_STD"
file_output = "perfomance_curve.pdf"
vae_model.compare_methods(filename_nsga , filename_bo ,
                    file_output)

# %%
# df1 = pd.DataFrame(data= MOBO.all_objectives.numpy() , columns=['pureza', 'FEDI'])
# df2 = pd.DataFrame(data= data_all , columns=['x1','x2','x3','x4','x5', 'x6', 'x7'] )
# df = pd.concat([df1,df2], axis= 1)
# df = df.drop_duplicates()
# df.to_csv(r'Intensified_MOBO.csv', index=False)
