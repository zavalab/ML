# %%
import os
project_dir = "c:/Users/sqin34/OneDrive - UW-Madison/Research/solvgnn/"
os.chdir(project_dir)

# %%
import pickle
import torch
from solvgnn.model.model_GNN import solvcat_ternary, get_n_params
from solvgnn.util.generate_dataset import solvent_dataset_ternary
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
# Out:
# Using backend: pytorch

# %%
plt.rcParams.update({
    'text.usetex': True,
    'font.family':'serif',
    'font.serif':['Computer Modern'],
    'axes.labelsize':10,
    'xtick.labelsize':9,
    'ytick.labelsize':9})

# %%
saved_model_dir = project_dir + "results/job_220822_solvcat_ternary_catx_randflip/"

# %%
valid_ind_list = np.load(saved_model_dir + 'saved_model/valid_ind_list.npy')
valid_loss_list = []
for cv_id in range(5):
    valid_loss_list.append(np.load(saved_model_dir + 'saved_model/val_loss_cv{}.npy'.format(cv_id))[-1])
print("mean CV loss {:.4f}, std CV loss {:.4f}".format(np.mean(valid_loss_list), np.std(valid_loss_list)))
best_cv_id = np.argmin(valid_loss_list)
print("best CV fold: {}".format(best_cv_id))
# Out:
# mean CV loss 0.0107, std CV loss 0.0004
# best CV fold: 3

# %%
idx_all = []
true_gam1_all, true_gam2_all, true_gam3_all = [], [], []
pred_gam1_all, pred_gam2_all, pred_gam3_all = [], [], []
intra_hb1_all, intra_hb2_all, intra_hb3_all = [], [], []
inter_hb12_all, inter_hb13_all, inter_hb23_all = [], [], []
solv1_x_all, solv2_x_all = [], []

# %%
dataset_path = project_dir + "solvgnn/data/output_ternary_all.csv"
solvent_list_path = project_dir + 'solvgnn/data/solvent_list.csv'
dataset = solvent_dataset_ternary(
    input_file_path=dataset_path,
    solvent_list_path = solvent_list_path,
    generate_all=True)

# %%
cv_id = 0
valid_ind = valid_ind_list[cv_id]
empty_solvsys = dataset.generate_solvsys(batch_size=1)
model = solvcat_ternary(in_dim=74, hidden_dim=256, n_classes=3).cuda()
checkpoint = torch.load(saved_model_dir + 'saved_model/final_model_cv{}.pth'.format(cv_id))
print("# model params: {}".format(get_n_params(model)))
model.load_state_dict(checkpoint['model_state_dict'])
model.eval()
# Out:
# # model params: 349187
# solvcat_ternary(
#   (conv1): GraphConv(in=74, out=256, normalization=both, activation=None)
#   (conv2): GraphConv(in=256, out=256, normalization=both, activation=None)
#   (classify1): Linear(in_features=771, out_features=256, bias=True)
#   (classify2): Linear(in_features=256, out_features=256, bias=True)
#   (classify3): Linear(in_features=256, out_features=3, bias=True)
# )

# %%
for cv_id in range(5):
    print('Analayzing CV {}'.format(cv_id+1))
    valid_ind = valid_ind_list[cv_id]
    model = solvcat_ternary(in_dim=74, hidden_dim=256, n_classes=3).cuda()
    checkpoint = torch.load(saved_model_dir + 'saved_model/final_model_cv{}.pth'.format(cv_id))
    model.load_state_dict(checkpoint['model_state_dict'])
    model.eval()
    for count,idx in enumerate(valid_ind):
        idx_all.append(idx)
        intra_hb1_all.append(dataset[idx]['intra_hb1'])
        intra_hb2_all.append(dataset[idx]['intra_hb2'])
        intra_hb3_all.append(dataset[idx]['intra_hb3'])
        inter_hb12_all.append(dataset[idx]['inter_hb12'])
        inter_hb13_all.append(dataset[idx]['inter_hb13'])
        inter_hb23_all.append(dataset[idx]['inter_hb23'])
        solv1_x_all.append(dataset[idx]['solv1_x'])
        solv2_x_all.append(dataset[idx]['solv2_x'])
        true,pred = dataset.predict(idx,model)
        pred_gam1_all.append(pred[0])
        pred_gam2_all.append(pred[1])
        pred_gam3_all.append(pred[2])
        true_gam1_all.append(true[0])
        true_gam2_all.append(true[1])
        true_gam3_all.append(true[2])
        if (count+1) % 100 == 0:
            print('{} out of {} done!'.format(count+1,len(valid_ind)))
# Out:
# Analayzing CV 1
# 100 out of 32000 done!
# 200 out of 32000 done!
# 300 out of 32000 done!
# 400 out of 32000 done!
# 500 out of 32000 done!
# 600 out of 32000 done!
# 700 out of 32000 done!
# 800 out of 32000 done!
# 900 out of 32000 done!
# 1000 out of 32000 done!
# 1100 out of 32000 done!
# 1200 out of 32000 done!
# 1300 out of 32000 done!
# 1400 out of 32000 done!
# 1500 out of 32000 done!
# 1600 out of 32000 done!
# 1700 out of 32000 done!
# 1800 out of 32000 done!
# 1900 out of 32000 done!
# 2000 out of 32000 done!
# 2100 out of 32000 done!
# 2200 out of 32000 done!
# 2300 out of 32000 done!
# 2400 out of 32000 done!
# 2500 out of 32000 done!
# 2600 out of 32000 done!
# 2700 out of 32000 done!
# 2800 out of 32000 done!
# 2900 out of 32000 done!
# 3000 out of 32000 done!
# 3100 out of 32000 done!
# 3200 out of 32000 done!
# 3300 out of 32000 done!
# 3400 out of 32000 done!
# 3500 out of 32000 done!
# 3600 out of 32000 done!
# 3700 out of 32000 done!
# 3800 out of 32000 done!
# 3900 out of 32000 done!
# 4000 out of 32000 done!
# 4100 out of 32000 done!
# 4200 out of 32000 done!
# 4300 out of 32000 done!
# 4400 out of 32000 done!
# 4500 out of 32000 done!
# 4600 out of 32000 done!
# 4700 out of 32000 done!
# 4800 out of 32000 done!
# 4900 out of 32000 done!
# 5000 out of 32000 done!
# 5100 out of 32000 done!
# 5200 out of 32000 done!
# 5300 out of 32000 done!
# 5400 out of 32000 done!
# 5500 out of 32000 done!
# 5600 out of 32000 done!
# 5700 out of 32000 done!
# 5800 out of 32000 done!
# 5900 out of 32000 done!
# 6000 out of 32000 done!
# 6100 out of 32000 done!
# 6200 out of 32000 done!
# 6300 out of 32000 done!
# 6400 out of 32000 done!
# 6500 out of 32000 done!
# 6600 out of 32000 done!
# 6700 out of 32000 done!
# 6800 out of 32000 done!
# 6900 out of 32000 done!
# 7000 out of 32000 done!
# 7100 out of 32000 done!
# 7200 out of 32000 done!
# 7300 out of 32000 done!
# 7400 out of 32000 done!
# 7500 out of 32000 done!
# 7600 out of 32000 done!
# 7700 out of 32000 done!
# 7800 out of 32000 done!
# 7900 out of 32000 done!
# 8000 out of 32000 done!
# 8100 out of 32000 done!
# 8200 out of 32000 done!
# 8300 out of 32000 done!
# 8400 out of 32000 done!
# 8500 out of 32000 done!
# 8600 out of 32000 done!
# 8700 out of 32000 done!
# 8800 out of 32000 done!
# 8900 out of 32000 done!
# 9000 out of 32000 done!
# 9100 out of 32000 done!
# 9200 out of 32000 done!
# 9300 out of 32000 done!
# 9400 out of 32000 done!
# 9500 out of 32000 done!
# 9600 out of 32000 done!
# 9700 out of 32000 done!
# 9800 out of 32000 done!
# 9900 out of 32000 done!
# 10000 out of 32000 done!
# 10100 out of 32000 done!
# 10200 out of 32000 done!
# 10300 out of 32000 done!
# 10400 out of 32000 done!
# 10500 out of 32000 done!
# 10600 out of 32000 done!
# 10700 out of 32000 done!
# 10800 out of 32000 done!
# 10900 out of 32000 done!
# 11000 out of 32000 done!
# 11100 out of 32000 done!
# 11200 out of 32000 done!
# 11300 out of 32000 done!
# 11400 out of 32000 done!
# 11500 out of 32000 done!
# 11600 out of 32000 done!
# 11700 out of 32000 done!
# 11800 out of 32000 done!
# 11900 out of 32000 done!
# 12000 out of 32000 done!
# 12100 out of 32000 done!
# 12200 out of 32000 done!
# 12300 out of 32000 done!
# 12400 out of 32000 done!
# 12500 out of 32000 done!
# 12600 out of 32000 done!
# 12700 out of 32000 done!
# 12800 out of 32000 done!
# 12900 out of 32000 done!
# 13000 out of 32000 done!
# 13100 out of 32000 done!
# 13200 out of 32000 done!
# 13300 out of 32000 done!
# 13400 out of 32000 done!
# 13500 out of 32000 done!
# 13600 out of 32000 done!
# 13700 out of 32000 done!
# 13800 out of 32000 done!
# 13900 out of 32000 done!
# 14000 out of 32000 done!
# 14100 out of 32000 done!
# 14200 out of 32000 done!
# 14300 out of 32000 done!
# 14400 out of 32000 done!
# 14500 out of 32000 done!
# 14600 out of 32000 done!
# 14700 out of 32000 done!
# 14800 out of 32000 done!
# 14900 out of 32000 done!
# 15000 out of 32000 done!
# 15100 out of 32000 done!
# 15200 out of 32000 done!
# 15300 out of 32000 done!
# 15400 out of 32000 done!
# 15500 out of 32000 done!
# 15600 out of 32000 done!
# 15700 out of 32000 done!
# 15800 out of 32000 done!
# 15900 out of 32000 done!
# 16000 out of 32000 done!
# 16100 out of 32000 done!
# 16200 out of 32000 done!
# 16300 out of 32000 done!
# 16400 out of 32000 done!
# 16500 out of 32000 done!
# 16600 out of 32000 done!
# 16700 out of 32000 done!
# 16800 out of 32000 done!
# 16900 out of 32000 done!
# 17000 out of 32000 done!
# 17100 out of 32000 done!
# 17200 out of 32000 done!
# 17300 out of 32000 done!
# 17400 out of 32000 done!
# 17500 out of 32000 done!
# 17600 out of 32000 done!
# 17700 out of 32000 done!
# 17800 out of 32000 done!
# 17900 out of 32000 done!
# 18000 out of 32000 done!
# 18100 out of 32000 done!
# 18200 out of 32000 done!
# 18300 out of 32000 done!
# 18400 out of 32000 done!
# 18500 out of 32000 done!
# 18600 out of 32000 done!
# 18700 out of 32000 done!
# 18800 out of 32000 done!
# 18900 out of 32000 done!
# 19000 out of 32000 done!
# 19100 out of 32000 done!
# 19200 out of 32000 done!
# 19300 out of 32000 done!
# 19400 out of 32000 done!
# 19500 out of 32000 done!
# 19600 out of 32000 done!
# 19700 out of 32000 done!
# 19800 out of 32000 done!
# 19900 out of 32000 done!
# 20000 out of 32000 done!
# 20100 out of 32000 done!
# 20200 out of 32000 done!
# 20300 out of 32000 done!
# 20400 out of 32000 done!
# 20500 out of 32000 done!
# 20600 out of 32000 done!
# 20700 out of 32000 done!
# 20800 out of 32000 done!
# 20900 out of 32000 done!
# 21000 out of 32000 done!
# 21100 out of 32000 done!
# 21200 out of 32000 done!
# 21300 out of 32000 done!
# 21400 out of 32000 done!
# 21500 out of 32000 done!
# 21600 out of 32000 done!
# 21700 out of 32000 done!
# 21800 out of 32000 done!
# 21900 out of 32000 done!
# 22000 out of 32000 done!
# 22100 out of 32000 done!
# 22200 out of 32000 done!
# 22300 out of 32000 done!
# 22400 out of 32000 done!
# 22500 out of 32000 done!
# 22600 out of 32000 done!
# 22700 out of 32000 done!
# 22800 out of 32000 done!
# 22900 out of 32000 done!
# 23000 out of 32000 done!
# 23100 out of 32000 done!
# 23200 out of 32000 done!
# 23300 out of 32000 done!
# 23400 out of 32000 done!
# 23500 out of 32000 done!
# 23600 out of 32000 done!
# 23700 out of 32000 done!
# 23800 out of 32000 done!
# 23900 out of 32000 done!
# 24000 out of 32000 done!
# 24100 out of 32000 done!
# 24200 out of 32000 done!
# 24300 out of 32000 done!
# 24400 out of 32000 done!
# 24500 out of 32000 done!
# 24600 out of 32000 done!
# 24700 out of 32000 done!
# 24800 out of 32000 done!
# 24900 out of 32000 done!
# 25000 out of 32000 done!
# 25100 out of 32000 done!
# 25200 out of 32000 done!
# 25300 out of 32000 done!
# 25400 out of 32000 done!
# 25500 out of 32000 done!
# 25600 out of 32000 done!
# 25700 out of 32000 done!
# 25800 out of 32000 done!
# 25900 out of 32000 done!
# 26000 out of 32000 done!
# 26100 out of 32000 done!
# 26200 out of 32000 done!
# 26300 out of 32000 done!
# 26400 out of 32000 done!
# 26500 out of 32000 done!
# 26600 out of 32000 done!
# 26700 out of 32000 done!
# 26800 out of 32000 done!
# 26900 out of 32000 done!
# 27000 out of 32000 done!
# 27100 out of 32000 done!
# 27200 out of 32000 done!
# 27300 out of 32000 done!
# 27400 out of 32000 done!
# 27500 out of 32000 done!
# 27600 out of 32000 done!
# 27700 out of 32000 done!
# 27800 out of 32000 done!
# 27900 out of 32000 done!
# 28000 out of 32000 done!
# 28100 out of 32000 done!
# 28200 out of 32000 done!
# 28300 out of 32000 done!
# 28400 out of 32000 done!
# 28500 out of 32000 done!
# 28600 out of 32000 done!
# 28700 out of 32000 done!
# 28800 out of 32000 done!
# 28900 out of 32000 done!
# 29000 out of 32000 done!
# 29100 out of 32000 done!
# 29200 out of 32000 done!
# 29300 out of 32000 done!
# 29400 out of 32000 done!
# 29500 out of 32000 done!
# 29600 out of 32000 done!
# 29700 out of 32000 done!
# 29800 out of 32000 done!
# 29900 out of 32000 done!
# 30000 out of 32000 done!
# 30100 out of 32000 done!
# 30200 out of 32000 done!
# 30300 out of 32000 done!
# 30400 out of 32000 done!
# 30500 out of 32000 done!
# 30600 out of 32000 done!
# 30700 out of 32000 done!
# 30800 out of 32000 done!
# 30900 out of 32000 done!
# 31000 out of 32000 done!
# 31100 out of 32000 done!
# 31200 out of 32000 done!
# 31300 out of 32000 done!
# 31400 out of 32000 done!
# 31500 out of 32000 done!
# 31600 out of 32000 done!
# 31700 out of 32000 done!
# 31800 out of 32000 done!
# 31900 out of 32000 done!
# 32000 out of 32000 done!
# Analayzing CV 2
# 100 out of 32000 done!
# 200 out of 32000 done!
# 300 out of 32000 done!
# 400 out of 32000 done!
# 500 out of 32000 done!
# 600 out of 32000 done!
# 700 out of 32000 done!
# 800 out of 32000 done!
# 900 out of 32000 done!
# 1000 out of 32000 done!
# 1100 out of 32000 done!
# 1200 out of 32000 done!
# 1300 out of 32000 done!
# 1400 out of 32000 done!
# 1500 out of 32000 done!
# 1600 out of 32000 done!
# 1700 out of 32000 done!
# 1800 out of 32000 done!
# 1900 out of 32000 done!
# 2000 out of 32000 done!
# 2100 out of 32000 done!
# 2200 out of 32000 done!
# 2300 out of 32000 done!
# 2400 out of 32000 done!
# 2500 out of 32000 done!
# 2600 out of 32000 done!
# 2700 out of 32000 done!
# 2800 out of 32000 done!
# 2900 out of 32000 done!
# 3000 out of 32000 done!
# 3100 out of 32000 done!
# 3200 out of 32000 done!
# 3300 out of 32000 done!
# 3400 out of 32000 done!
# 3500 out of 32000 done!
# 3600 out of 32000 done!
# 3700 out of 32000 done!
# 3800 out of 32000 done!
# 3900 out of 32000 done!
# 4000 out of 32000 done!
# 4100 out of 32000 done!
# 4200 out of 32000 done!
# 4300 out of 32000 done!
# 4400 out of 32000 done!
# 4500 out of 32000 done!
# 4600 out of 32000 done!
# 4700 out of 32000 done!
# 4800 out of 32000 done!
# 4900 out of 32000 done!
# 5000 out of 32000 done!
# 5100 out of 32000 done!
# 5200 out of 32000 done!
# 5300 out of 32000 done!
# 5400 out of 32000 done!
# 5500 out of 32000 done!
# 5600 out of 32000 done!
# 5700 out of 32000 done!
# 5800 out of 32000 done!
# 5900 out of 32000 done!
# 6000 out of 32000 done!
# 6100 out of 32000 done!
# 6200 out of 32000 done!
# 6300 out of 32000 done!
# 6400 out of 32000 done!
# 6500 out of 32000 done!
# 6600 out of 32000 done!
# 6700 out of 32000 done!
# 6800 out of 32000 done!
# 6900 out of 32000 done!
# 7000 out of 32000 done!
# 7100 out of 32000 done!
# 7200 out of 32000 done!
# 7300 out of 32000 done!
# 7400 out of 32000 done!
# 7500 out of 32000 done!
# 7600 out of 32000 done!
# 7700 out of 32000 done!
# 7800 out of 32000 done!
# 7900 out of 32000 done!
# 8000 out of 32000 done!
# 8100 out of 32000 done!
# 8200 out of 32000 done!
# 8300 out of 32000 done!
# 8400 out of 32000 done!
# 8500 out of 32000 done!
# 8600 out of 32000 done!
# 8700 out of 32000 done!
# 8800 out of 32000 done!
# 8900 out of 32000 done!
# 9000 out of 32000 done!
# 9100 out of 32000 done!
# 9200 out of 32000 done!
# 9300 out of 32000 done!
# 9400 out of 32000 done!
# 9500 out of 32000 done!
# 9600 out of 32000 done!
# 9700 out of 32000 done!
# 9800 out of 32000 done!
# 9900 out of 32000 done!
# 10000 out of 32000 done!
# 10100 out of 32000 done!
# 10200 out of 32000 done!
# 10300 out of 32000 done!
# 10400 out of 32000 done!
# 10500 out of 32000 done!
# 10600 out of 32000 done!
# 10700 out of 32000 done!
# 10800 out of 32000 done!
# 10900 out of 32000 done!
# 11000 out of 32000 done!
# 11100 out of 32000 done!
# 11200 out of 32000 done!
# 11300 out of 32000 done!
# 11400 out of 32000 done!
# 11500 out of 32000 done!
# 11600 out of 32000 done!
# 11700 out of 32000 done!
# 11800 out of 32000 done!
# 11900 out of 32000 done!
# 12000 out of 32000 done!
# 12100 out of 32000 done!
# 12200 out of 32000 done!
# 12300 out of 32000 done!
# 12400 out of 32000 done!
# 12500 out of 32000 done!
# 12600 out of 32000 done!
# 12700 out of 32000 done!
# 12800 out of 32000 done!
# 12900 out of 32000 done!
# 13000 out of 32000 done!
# 13100 out of 32000 done!
# 13200 out of 32000 done!
# 13300 out of 32000 done!
# 13400 out of 32000 done!
# 13500 out of 32000 done!
# 13600 out of 32000 done!
# 13700 out of 32000 done!
# 13800 out of 32000 done!
# 13900 out of 32000 done!
# 14000 out of 32000 done!
# 14100 out of 32000 done!
# 14200 out of 32000 done!
# 14300 out of 32000 done!
# 14400 out of 32000 done!
# 14500 out of 32000 done!
# 14600 out of 32000 done!
# 14700 out of 32000 done!
# 14800 out of 32000 done!
# 14900 out of 32000 done!
# 15000 out of 32000 done!
# 15100 out of 32000 done!
# 15200 out of 32000 done!
# 15300 out of 32000 done!
# 15400 out of 32000 done!
# 15500 out of 32000 done!
# 15600 out of 32000 done!
# 15700 out of 32000 done!
# 15800 out of 32000 done!
# 15900 out of 32000 done!
# 16000 out of 32000 done!
# 16100 out of 32000 done!
# 16200 out of 32000 done!
# 16300 out of 32000 done!
# 16400 out of 32000 done!
# 16500 out of 32000 done!
# 16600 out of 32000 done!
# 16700 out of 32000 done!
# 16800 out of 32000 done!
# 16900 out of 32000 done!
# 17000 out of 32000 done!
# 17100 out of 32000 done!
# 17200 out of 32000 done!
# 17300 out of 32000 done!
# 17400 out of 32000 done!
# 17500 out of 32000 done!
# 17600 out of 32000 done!
# 17700 out of 32000 done!
# 17800 out of 32000 done!
# 17900 out of 32000 done!
# 18000 out of 32000 done!
# 18100 out of 32000 done!
# 18200 out of 32000 done!
# 18300 out of 32000 done!
# 18400 out of 32000 done!
# 18500 out of 32000 done!
# 18600 out of 32000 done!
# 18700 out of 32000 done!
# 18800 out of 32000 done!
# 18900 out of 32000 done!
# 19000 out of 32000 done!
# 19100 out of 32000 done!
# 19200 out of 32000 done!
# 19300 out of 32000 done!
# 19400 out of 32000 done!
# 19500 out of 32000 done!
# 19600 out of 32000 done!
# 19700 out of 32000 done!
# 19800 out of 32000 done!
# 19900 out of 32000 done!
# 20000 out of 32000 done!
# 20100 out of 32000 done!
# 20200 out of 32000 done!
# 20300 out of 32000 done!
# 20400 out of 32000 done!
# 20500 out of 32000 done!
# 20600 out of 32000 done!
# 20700 out of 32000 done!
# 20800 out of 32000 done!
# 20900 out of 32000 done!
# 21000 out of 32000 done!
# 21100 out of 32000 done!
# 21200 out of 32000 done!
# 21300 out of 32000 done!
# 21400 out of 32000 done!
# 21500 out of 32000 done!
# 21600 out of 32000 done!
# 21700 out of 32000 done!
# 21800 out of 32000 done!
# 21900 out of 32000 done!
# 22000 out of 32000 done!
# 22100 out of 32000 done!
# 22200 out of 32000 done!
# 22300 out of 32000 done!
# 22400 out of 32000 done!
# 22500 out of 32000 done!
# 22600 out of 32000 done!
# 22700 out of 32000 done!
# 22800 out of 32000 done!
# 22900 out of 32000 done!
# 23000 out of 32000 done!
# 23100 out of 32000 done!
# 23200 out of 32000 done!
# 23300 out of 32000 done!
# 23400 out of 32000 done!
# 23500 out of 32000 done!
# 23600 out of 32000 done!
# 23700 out of 32000 done!
# 23800 out of 32000 done!
# 23900 out of 32000 done!
# 24000 out of 32000 done!
# 24100 out of 32000 done!
# 24200 out of 32000 done!
# 24300 out of 32000 done!
# 24400 out of 32000 done!
# 24500 out of 32000 done!
# 24600 out of 32000 done!
# 24700 out of 32000 done!
# 24800 out of 32000 done!
# 24900 out of 32000 done!
# 25000 out of 32000 done!
# 25100 out of 32000 done!
# 25200 out of 32000 done!
# 25300 out of 32000 done!
# 25400 out of 32000 done!
# 25500 out of 32000 done!
# 25600 out of 32000 done!
# 25700 out of 32000 done!
# 25800 out of 32000 done!
# 25900 out of 32000 done!
# 26000 out of 32000 done!
# 26100 out of 32000 done!
# 26200 out of 32000 done!
# 26300 out of 32000 done!
# 26400 out of 32000 done!
# 26500 out of 32000 done!
# 26600 out of 32000 done!
# 26700 out of 32000 done!
# 26800 out of 32000 done!
# 26900 out of 32000 done!
# 27000 out of 32000 done!
# 27100 out of 32000 done!
# 27200 out of 32000 done!
# 27300 out of 32000 done!
# 27400 out of 32000 done!
# 27500 out of 32000 done!
# 27600 out of 32000 done!
# 27700 out of 32000 done!
# 27800 out of 32000 done!
# 27900 out of 32000 done!
# 28000 out of 32000 done!
# 28100 out of 32000 done!
# 28200 out of 32000 done!
# 28300 out of 32000 done!
# 28400 out of 32000 done!
# 28500 out of 32000 done!
# 28600 out of 32000 done!
# 28700 out of 32000 done!
# 28800 out of 32000 done!
# 28900 out of 32000 done!
# 29000 out of 32000 done!
# 29100 out of 32000 done!
# 29200 out of 32000 done!
# 29300 out of 32000 done!
# 29400 out of 32000 done!
# 29500 out of 32000 done!
# 29600 out of 32000 done!
# 29700 out of 32000 done!
# 29800 out of 32000 done!
# 29900 out of 32000 done!
# 30000 out of 32000 done!
# 30100 out of 32000 done!
# 30200 out of 32000 done!
# 30300 out of 32000 done!
# 30400 out of 32000 done!
# 30500 out of 32000 done!
# 30600 out of 32000 done!
# 30700 out of 32000 done!
# 30800 out of 32000 done!
# 30900 out of 32000 done!
# 31000 out of 32000 done!
# 31100 out of 32000 done!
# 31200 out of 32000 done!
# 31300 out of 32000 done!
# 31400 out of 32000 done!
# 31500 out of 32000 done!
# 31600 out of 32000 done!
# 31700 out of 32000 done!
# 31800 out of 32000 done!
# 31900 out of 32000 done!
# 32000 out of 32000 done!
# Analayzing CV 3
# 100 out of 32000 done!
# 200 out of 32000 done!
# 300 out of 32000 done!
# 400 out of 32000 done!
# 500 out of 32000 done!
# 600 out of 32000 done!
# 700 out of 32000 done!
# 800 out of 32000 done!
# 900 out of 32000 done!
# 1000 out of 32000 done!
# 1100 out of 32000 done!
# 1200 out of 32000 done!
# 1300 out of 32000 done!
# 1400 out of 32000 done!
# 1500 out of 32000 done!
# 1600 out of 32000 done!
# 1700 out of 32000 done!
# 1800 out of 32000 done!
# 1900 out of 32000 done!
# 2000 out of 32000 done!
# 2100 out of 32000 done!
# 2200 out of 32000 done!
# 2300 out of 32000 done!
# 2400 out of 32000 done!
# 2500 out of 32000 done!
# 2600 out of 32000 done!
# 2700 out of 32000 done!
# 2800 out of 32000 done!
# 2900 out of 32000 done!
# 3000 out of 32000 done!
# 3100 out of 32000 done!
# 3200 out of 32000 done!
# 3300 out of 32000 done!
# 3400 out of 32000 done!
# 3500 out of 32000 done!
# 3600 out of 32000 done!
# 3700 out of 32000 done!
# 3800 out of 32000 done!
# 3900 out of 32000 done!
# 4000 out of 32000 done!
# 4100 out of 32000 done!
# 4200 out of 32000 done!
# 4300 out of 32000 done!
# 4400 out of 32000 done!
# 4500 out of 32000 done!
# 4600 out of 32000 done!
# 4700 out of 32000 done!
# 4800 out of 32000 done!
# 4900 out of 32000 done!
# 5000 out of 32000 done!
# 5100 out of 32000 done!
# 5200 out of 32000 done!
# 5300 out of 32000 done!
# 5400 out of 32000 done!
# 5500 out of 32000 done!
# 5600 out of 32000 done!
# 5700 out of 32000 done!
# 5800 out of 32000 done!
# 5900 out of 32000 done!
# 6000 out of 32000 done!
# 6100 out of 32000 done!
# 6200 out of 32000 done!
# 6300 out of 32000 done!
# 6400 out of 32000 done!
# 6500 out of 32000 done!
# 6600 out of 32000 done!
# 6700 out of 32000 done!
# 6800 out of 32000 done!
# 6900 out of 32000 done!
# 7000 out of 32000 done!
# 7100 out of 32000 done!
# 7200 out of 32000 done!
# 7300 out of 32000 done!
# 7400 out of 32000 done!
# 7500 out of 32000 done!
# 7600 out of 32000 done!
# 7700 out of 32000 done!
# 7800 out of 32000 done!
# 7900 out of 32000 done!
# 8000 out of 32000 done!
# 8100 out of 32000 done!
# 8200 out of 32000 done!
# 8300 out of 32000 done!
# 8400 out of 32000 done!
# 8500 out of 32000 done!
# 8600 out of 32000 done!
# 8700 out of 32000 done!
# 8800 out of 32000 done!
# 8900 out of 32000 done!
# 9000 out of 32000 done!
# 9100 out of 32000 done!
# 9200 out of 32000 done!
# 9300 out of 32000 done!
# 9400 out of 32000 done!
# 9500 out of 32000 done!
# 9600 out of 32000 done!
# 9700 out of 32000 done!
# 9800 out of 32000 done!
# 9900 out of 32000 done!
# 10000 out of 32000 done!
# 10100 out of 32000 done!
# 10200 out of 32000 done!
# 10300 out of 32000 done!
# 10400 out of 32000 done!
# 10500 out of 32000 done!
# 10600 out of 32000 done!
# 10700 out of 32000 done!
# 10800 out of 32000 done!
# 10900 out of 32000 done!
# 11000 out of 32000 done!
# 11100 out of 32000 done!
# 11200 out of 32000 done!
# 11300 out of 32000 done!
# 11400 out of 32000 done!
# 11500 out of 32000 done!
# 11600 out of 32000 done!
# 11700 out of 32000 done!
# 11800 out of 32000 done!
# 11900 out of 32000 done!
# 12000 out of 32000 done!
# 12100 out of 32000 done!
# 12200 out of 32000 done!
# 12300 out of 32000 done!
# 12400 out of 32000 done!
# 12500 out of 32000 done!
# 12600 out of 32000 done!
# 12700 out of 32000 done!
# 12800 out of 32000 done!
# 12900 out of 32000 done!
# 13000 out of 32000 done!
# 13100 out of 32000 done!
# 13200 out of 32000 done!
# 13300 out of 32000 done!
# 13400 out of 32000 done!
# 13500 out of 32000 done!
# 13600 out of 32000 done!
# 13700 out of 32000 done!
# 13800 out of 32000 done!
# 13900 out of 32000 done!
# 14000 out of 32000 done!
# 14100 out of 32000 done!
# 14200 out of 32000 done!
# 14300 out of 32000 done!
# 14400 out of 32000 done!
# 14500 out of 32000 done!
# 14600 out of 32000 done!
# 14700 out of 32000 done!
# 14800 out of 32000 done!
# 14900 out of 32000 done!
# 15000 out of 32000 done!
# 15100 out of 32000 done!
# 15200 out of 32000 done!
# 15300 out of 32000 done!
# 15400 out of 32000 done!
# 15500 out of 32000 done!
# 15600 out of 32000 done!
# 15700 out of 32000 done!
# 15800 out of 32000 done!
# 15900 out of 32000 done!
# 16000 out of 32000 done!
# 16100 out of 32000 done!
# 16200 out of 32000 done!
# 16300 out of 32000 done!
# 16400 out of 32000 done!
# 16500 out of 32000 done!
# 16600 out of 32000 done!
# 16700 out of 32000 done!
# 16800 out of 32000 done!
# 16900 out of 32000 done!
# 17000 out of 32000 done!
# 17100 out of 32000 done!
# 17200 out of 32000 done!
# 17300 out of 32000 done!
# 17400 out of 32000 done!
# 17500 out of 32000 done!
# 17600 out of 32000 done!
# 17700 out of 32000 done!
# 17800 out of 32000 done!
# 17900 out of 32000 done!
# 18000 out of 32000 done!
# 18100 out of 32000 done!
# 18200 out of 32000 done!
# 18300 out of 32000 done!
# 18400 out of 32000 done!
# 18500 out of 32000 done!
# 18600 out of 32000 done!
# 18700 out of 32000 done!
# 18800 out of 32000 done!
# 18900 out of 32000 done!
# 19000 out of 32000 done!
# 19100 out of 32000 done!
# 19200 out of 32000 done!
# 19300 out of 32000 done!
# 19400 out of 32000 done!
# 19500 out of 32000 done!
# 19600 out of 32000 done!
# 19700 out of 32000 done!
# 19800 out of 32000 done!
# 19900 out of 32000 done!
# 20000 out of 32000 done!
# 20100 out of 32000 done!
# 20200 out of 32000 done!
# 20300 out of 32000 done!
# 20400 out of 32000 done!
# 20500 out of 32000 done!
# 20600 out of 32000 done!
# 20700 out of 32000 done!
# 20800 out of 32000 done!
# 20900 out of 32000 done!
# 21000 out of 32000 done!
# 21100 out of 32000 done!
# 21200 out of 32000 done!
# 21300 out of 32000 done!
# 21400 out of 32000 done!
# 21500 out of 32000 done!
# 21600 out of 32000 done!
# 21700 out of 32000 done!
# 21800 out of 32000 done!
# 21900 out of 32000 done!
# 22000 out of 32000 done!
# 22100 out of 32000 done!
# 22200 out of 32000 done!
# 22300 out of 32000 done!
# 22400 out of 32000 done!
# 22500 out of 32000 done!
# 22600 out of 32000 done!
# 22700 out of 32000 done!
# 22800 out of 32000 done!
# 22900 out of 32000 done!
# 23000 out of 32000 done!
# 23100 out of 32000 done!
# 23200 out of 32000 done!
# 23300 out of 32000 done!
# 23400 out of 32000 done!
# 23500 out of 32000 done!
# 23600 out of 32000 done!
# 23700 out of 32000 done!
# 23800 out of 32000 done!
# 23900 out of 32000 done!
# 24000 out of 32000 done!
# 24100 out of 32000 done!
# 24200 out of 32000 done!
# 24300 out of 32000 done!
# 24400 out of 32000 done!
# 24500 out of 32000 done!
# 24600 out of 32000 done!
# 24700 out of 32000 done!
# 24800 out of 32000 done!
# 24900 out of 32000 done!
# 25000 out of 32000 done!
# 25100 out of 32000 done!
# 25200 out of 32000 done!
# 25300 out of 32000 done!
# 25400 out of 32000 done!
# 25500 out of 32000 done!
# 25600 out of 32000 done!
# 25700 out of 32000 done!
# 25800 out of 32000 done!
# 25900 out of 32000 done!
# 26000 out of 32000 done!
# 26100 out of 32000 done!
# 26200 out of 32000 done!
# 26300 out of 32000 done!
# 26400 out of 32000 done!
# 26500 out of 32000 done!
# 26600 out of 32000 done!
# 26700 out of 32000 done!
# 26800 out of 32000 done!
# 26900 out of 32000 done!
# 27000 out of 32000 done!
# 27100 out of 32000 done!
# 27200 out of 32000 done!
# 27300 out of 32000 done!
# 27400 out of 32000 done!
# 27500 out of 32000 done!
# 27600 out of 32000 done!
# 27700 out of 32000 done!
# 27800 out of 32000 done!
# 27900 out of 32000 done!
# 28000 out of 32000 done!
# 28100 out of 32000 done!
# 28200 out of 32000 done!
# 28300 out of 32000 done!
# 28400 out of 32000 done!
# 28500 out of 32000 done!
# 28600 out of 32000 done!
# 28700 out of 32000 done!
# 28800 out of 32000 done!
# 28900 out of 32000 done!
# 29000 out of 32000 done!
# 29100 out of 32000 done!
# 29200 out of 32000 done!
# 29300 out of 32000 done!
# 29400 out of 32000 done!
# 29500 out of 32000 done!
# 29600 out of 32000 done!
# 29700 out of 32000 done!
# 29800 out of 32000 done!
# 29900 out of 32000 done!
# 30000 out of 32000 done!
# 30100 out of 32000 done!
# 30200 out of 32000 done!
# 30300 out of 32000 done!
# 30400 out of 32000 done!
# 30500 out of 32000 done!
# 30600 out of 32000 done!
# 30700 out of 32000 done!
# 30800 out of 32000 done!
# 30900 out of 32000 done!
# 31000 out of 32000 done!
# 31100 out of 32000 done!
# 31200 out of 32000 done!
# 31300 out of 32000 done!
# 31400 out of 32000 done!
# 31500 out of 32000 done!
# 31600 out of 32000 done!
# 31700 out of 32000 done!
# 31800 out of 32000 done!
# 31900 out of 32000 done!
# 32000 out of 32000 done!
# Analayzing CV 4
# 100 out of 32000 done!
# 200 out of 32000 done!
# 300 out of 32000 done!
# 400 out of 32000 done!
# 500 out of 32000 done!
# 600 out of 32000 done!
# 700 out of 32000 done!
# 800 out of 32000 done!
# 900 out of 32000 done!
# 1000 out of 32000 done!
# 1100 out of 32000 done!
# 1200 out of 32000 done!
# 1300 out of 32000 done!
# 1400 out of 32000 done!
# 1500 out of 32000 done!
# 1600 out of 32000 done!
# 1700 out of 32000 done!
# 1800 out of 32000 done!
# 1900 out of 32000 done!
# 2000 out of 32000 done!
# 2100 out of 32000 done!
# 2200 out of 32000 done!
# 2300 out of 32000 done!
# 2400 out of 32000 done!
# 2500 out of 32000 done!
# 2600 out of 32000 done!
# 2700 out of 32000 done!
# 2800 out of 32000 done!
# 2900 out of 32000 done!
# 3000 out of 32000 done!
# 3100 out of 32000 done!
# 3200 out of 32000 done!
# 3300 out of 32000 done!
# 3400 out of 32000 done!
# 3500 out of 32000 done!
# 3600 out of 32000 done!
# 3700 out of 32000 done!
# 3800 out of 32000 done!
# 3900 out of 32000 done!
# 4000 out of 32000 done!
# 4100 out of 32000 done!
# 4200 out of 32000 done!
# 4300 out of 32000 done!
# 4400 out of 32000 done!
# 4500 out of 32000 done!
# 4600 out of 32000 done!
# 4700 out of 32000 done!
# 4800 out of 32000 done!
# 4900 out of 32000 done!
# 5000 out of 32000 done!
# 5100 out of 32000 done!
# 5200 out of 32000 done!
# 5300 out of 32000 done!
# 5400 out of 32000 done!
# 5500 out of 32000 done!
# 5600 out of 32000 done!
# 5700 out of 32000 done!
# 5800 out of 32000 done!
# 5900 out of 32000 done!
# 6000 out of 32000 done!
# 6100 out of 32000 done!
# 6200 out of 32000 done!
# 6300 out of 32000 done!
# 6400 out of 32000 done!
# 6500 out of 32000 done!
# 6600 out of 32000 done!
# 6700 out of 32000 done!
# 6800 out of 32000 done!
# 6900 out of 32000 done!
# 7000 out of 32000 done!
# 7100 out of 32000 done!
# 7200 out of 32000 done!
# 7300 out of 32000 done!
# 7400 out of 32000 done!
# 7500 out of 32000 done!
# 7600 out of 32000 done!
# 7700 out of 32000 done!
# 7800 out of 32000 done!
# 7900 out of 32000 done!
# 8000 out of 32000 done!
# 8100 out of 32000 done!
# 8200 out of 32000 done!
# 8300 out of 32000 done!
# 8400 out of 32000 done!
# 8500 out of 32000 done!
# 8600 out of 32000 done!
# 8700 out of 32000 done!
# 8800 out of 32000 done!
# 8900 out of 32000 done!
# 9000 out of 32000 done!
# 9100 out of 32000 done!
# 9200 out of 32000 done!
# 9300 out of 32000 done!
# 9400 out of 32000 done!
# 9500 out of 32000 done!
# 9600 out of 32000 done!
# 9700 out of 32000 done!
# 9800 out of 32000 done!
# 9900 out of 32000 done!
# 10000 out of 32000 done!
# 10100 out of 32000 done!
# 10200 out of 32000 done!
# 10300 out of 32000 done!
# 10400 out of 32000 done!
# 10500 out of 32000 done!
# 10600 out of 32000 done!
# 10700 out of 32000 done!
# 10800 out of 32000 done!
# 10900 out of 32000 done!
# 11000 out of 32000 done!
# 11100 out of 32000 done!
# 11200 out of 32000 done!
# 11300 out of 32000 done!
# 11400 out of 32000 done!
# 11500 out of 32000 done!
# 11600 out of 32000 done!
# 11700 out of 32000 done!
# 11800 out of 32000 done!
# 11900 out of 32000 done!
# 12000 out of 32000 done!
# 12100 out of 32000 done!
# 12200 out of 32000 done!
# 12300 out of 32000 done!
# 12400 out of 32000 done!
# 12500 out of 32000 done!
# 12600 out of 32000 done!
# 12700 out of 32000 done!
# 12800 out of 32000 done!
# 12900 out of 32000 done!
# 13000 out of 32000 done!
# 13100 out of 32000 done!
# 13200 out of 32000 done!
# 13300 out of 32000 done!
# 13400 out of 32000 done!
# 13500 out of 32000 done!
# 13600 out of 32000 done!
# 13700 out of 32000 done!
# 13800 out of 32000 done!
# 13900 out of 32000 done!
# 14000 out of 32000 done!
# 14100 out of 32000 done!
# 14200 out of 32000 done!
# 14300 out of 32000 done!
# 14400 out of 32000 done!
# 14500 out of 32000 done!
# 14600 out of 32000 done!
# 14700 out of 32000 done!
# 14800 out of 32000 done!
# 14900 out of 32000 done!
# 15000 out of 32000 done!
# 15100 out of 32000 done!
# 15200 out of 32000 done!
# 15300 out of 32000 done!
# 15400 out of 32000 done!
# 15500 out of 32000 done!
# 15600 out of 32000 done!
# 15700 out of 32000 done!
# 15800 out of 32000 done!
# 15900 out of 32000 done!
# 16000 out of 32000 done!
# 16100 out of 32000 done!
# 16200 out of 32000 done!
# 16300 out of 32000 done!
# 16400 out of 32000 done!
# 16500 out of 32000 done!
# 16600 out of 32000 done!
# 16700 out of 32000 done!
# 16800 out of 32000 done!
# 16900 out of 32000 done!
# 17000 out of 32000 done!
# 17100 out of 32000 done!
# 17200 out of 32000 done!
# 17300 out of 32000 done!
# 17400 out of 32000 done!
# 17500 out of 32000 done!
# 17600 out of 32000 done!
# 17700 out of 32000 done!
# 17800 out of 32000 done!
# 17900 out of 32000 done!
# 18000 out of 32000 done!
# 18100 out of 32000 done!
# 18200 out of 32000 done!
# 18300 out of 32000 done!
# 18400 out of 32000 done!
# 18500 out of 32000 done!
# 18600 out of 32000 done!
# 18700 out of 32000 done!
# 18800 out of 32000 done!
# 18900 out of 32000 done!
# 19000 out of 32000 done!
# 19100 out of 32000 done!
# 19200 out of 32000 done!
# 19300 out of 32000 done!
# 19400 out of 32000 done!
# 19500 out of 32000 done!
# 19600 out of 32000 done!
# 19700 out of 32000 done!
# 19800 out of 32000 done!
# 19900 out of 32000 done!
# 20000 out of 32000 done!
# 20100 out of 32000 done!
# 20200 out of 32000 done!
# 20300 out of 32000 done!
# 20400 out of 32000 done!
# 20500 out of 32000 done!
# 20600 out of 32000 done!
# 20700 out of 32000 done!
# 20800 out of 32000 done!
# 20900 out of 32000 done!
# 21000 out of 32000 done!
# 21100 out of 32000 done!
# 21200 out of 32000 done!
# 21300 out of 32000 done!
# 21400 out of 32000 done!
# 21500 out of 32000 done!
# 21600 out of 32000 done!
# 21700 out of 32000 done!
# 21800 out of 32000 done!
# 21900 out of 32000 done!
# 22000 out of 32000 done!
# 22100 out of 32000 done!
# 22200 out of 32000 done!
# 22300 out of 32000 done!
# 22400 out of 32000 done!
# 22500 out of 32000 done!
# 22600 out of 32000 done!
# 22700 out of 32000 done!
# 22800 out of 32000 done!
# 22900 out of 32000 done!
# 23000 out of 32000 done!
# 23100 out of 32000 done!
# 23200 out of 32000 done!
# 23300 out of 32000 done!
# 23400 out of 32000 done!
# 23500 out of 32000 done!
# 23600 out of 32000 done!
# 23700 out of 32000 done!
# 23800 out of 32000 done!
# 23900 out of 32000 done!
# 24000 out of 32000 done!
# 24100 out of 32000 done!
# 24200 out of 32000 done!
# 24300 out of 32000 done!
# 24400 out of 32000 done!
# 24500 out of 32000 done!
# 24600 out of 32000 done!
# 24700 out of 32000 done!
# 24800 out of 32000 done!
# 24900 out of 32000 done!
# 25000 out of 32000 done!
# 25100 out of 32000 done!
# 25200 out of 32000 done!
# 25300 out of 32000 done!
# 25400 out of 32000 done!
# 25500 out of 32000 done!
# 25600 out of 32000 done!
# 25700 out of 32000 done!
# 25800 out of 32000 done!
# 25900 out of 32000 done!
# 26000 out of 32000 done!
# 26100 out of 32000 done!
# 26200 out of 32000 done!
# 26300 out of 32000 done!
# 26400 out of 32000 done!
# 26500 out of 32000 done!
# 26600 out of 32000 done!
# 26700 out of 32000 done!
# 26800 out of 32000 done!
# 26900 out of 32000 done!
# 27000 out of 32000 done!
# 27100 out of 32000 done!
# 27200 out of 32000 done!
# 27300 out of 32000 done!
# 27400 out of 32000 done!
# 27500 out of 32000 done!
# 27600 out of 32000 done!
# 27700 out of 32000 done!
# 27800 out of 32000 done!
# 27900 out of 32000 done!
# 28000 out of 32000 done!
# 28100 out of 32000 done!
# 28200 out of 32000 done!
# 28300 out of 32000 done!
# 28400 out of 32000 done!
# 28500 out of 32000 done!
# 28600 out of 32000 done!
# 28700 out of 32000 done!
# 28800 out of 32000 done!
# 28900 out of 32000 done!
# 29000 out of 32000 done!
# 29100 out of 32000 done!
# 29200 out of 32000 done!
# 29300 out of 32000 done!
# 29400 out of 32000 done!
# 29500 out of 32000 done!
# 29600 out of 32000 done!
# 29700 out of 32000 done!
# 29800 out of 32000 done!
# 29900 out of 32000 done!
# 30000 out of 32000 done!
# 30100 out of 32000 done!
# 30200 out of 32000 done!
# 30300 out of 32000 done!
# 30400 out of 32000 done!
# 30500 out of 32000 done!
# 30600 out of 32000 done!
# 30700 out of 32000 done!
# 30800 out of 32000 done!
# 30900 out of 32000 done!
# 31000 out of 32000 done!
# 31100 out of 32000 done!
# 31200 out of 32000 done!
# 31300 out of 32000 done!
# 31400 out of 32000 done!
# 31500 out of 32000 done!
# 31600 out of 32000 done!
# 31700 out of 32000 done!
# 31800 out of 32000 done!
# 31900 out of 32000 done!
# 32000 out of 32000 done!
# Analayzing CV 5
# 100 out of 32000 done!
# 200 out of 32000 done!
# 300 out of 32000 done!
# 400 out of 32000 done!
# 500 out of 32000 done!
# 600 out of 32000 done!
# 700 out of 32000 done!
# 800 out of 32000 done!
# 900 out of 32000 done!
# 1000 out of 32000 done!
# 1100 out of 32000 done!
# 1200 out of 32000 done!
# 1300 out of 32000 done!
# 1400 out of 32000 done!
# 1500 out of 32000 done!
# 1600 out of 32000 done!
# 1700 out of 32000 done!
# 1800 out of 32000 done!
# 1900 out of 32000 done!
# 2000 out of 32000 done!
# 2100 out of 32000 done!
# 2200 out of 32000 done!
# 2300 out of 32000 done!
# 2400 out of 32000 done!
# 2500 out of 32000 done!
# 2600 out of 32000 done!
# 2700 out of 32000 done!
# 2800 out of 32000 done!
# 2900 out of 32000 done!
# 3000 out of 32000 done!
# 3100 out of 32000 done!
# 3200 out of 32000 done!
# 3300 out of 32000 done!
# 3400 out of 32000 done!
# 3500 out of 32000 done!
# 3600 out of 32000 done!
# 3700 out of 32000 done!
# 3800 out of 32000 done!
# 3900 out of 32000 done!
# 4000 out of 32000 done!
# 4100 out of 32000 done!
# 4200 out of 32000 done!
# 4300 out of 32000 done!
# 4400 out of 32000 done!
# 4500 out of 32000 done!
# 4600 out of 32000 done!
# 4700 out of 32000 done!
# 4800 out of 32000 done!
# 4900 out of 32000 done!
# 5000 out of 32000 done!
# 5100 out of 32000 done!
# 5200 out of 32000 done!
# 5300 out of 32000 done!
# 5400 out of 32000 done!
# 5500 out of 32000 done!
# 5600 out of 32000 done!
# 5700 out of 32000 done!
# 5800 out of 32000 done!
# 5900 out of 32000 done!
# 6000 out of 32000 done!
# 6100 out of 32000 done!
# 6200 out of 32000 done!
# 6300 out of 32000 done!
# 6400 out of 32000 done!
# 6500 out of 32000 done!
# 6600 out of 32000 done!
# 6700 out of 32000 done!
# 6800 out of 32000 done!
# 6900 out of 32000 done!
# 7000 out of 32000 done!
# 7100 out of 32000 done!
# 7200 out of 32000 done!
# 7300 out of 32000 done!
# 7400 out of 32000 done!
# 7500 out of 32000 done!
# 7600 out of 32000 done!
# 7700 out of 32000 done!
# 7800 out of 32000 done!
# 7900 out of 32000 done!
# 8000 out of 32000 done!
# 8100 out of 32000 done!
# 8200 out of 32000 done!
# 8300 out of 32000 done!
# 8400 out of 32000 done!
# 8500 out of 32000 done!
# 8600 out of 32000 done!
# 8700 out of 32000 done!
# 8800 out of 32000 done!
# 8900 out of 32000 done!
# 9000 out of 32000 done!
# 9100 out of 32000 done!
# 9200 out of 32000 done!
# 9300 out of 32000 done!
# 9400 out of 32000 done!
# 9500 out of 32000 done!
# 9600 out of 32000 done!
# 9700 out of 32000 done!
# 9800 out of 32000 done!
# 9900 out of 32000 done!
# 10000 out of 32000 done!
# 10100 out of 32000 done!
# 10200 out of 32000 done!
# 10300 out of 32000 done!
# 10400 out of 32000 done!
# 10500 out of 32000 done!
# 10600 out of 32000 done!
# 10700 out of 32000 done!
# 10800 out of 32000 done!
# 10900 out of 32000 done!
# 11000 out of 32000 done!
# 11100 out of 32000 done!
# 11200 out of 32000 done!
# 11300 out of 32000 done!
# 11400 out of 32000 done!
# 11500 out of 32000 done!
# 11600 out of 32000 done!
# 11700 out of 32000 done!
# 11800 out of 32000 done!
# 11900 out of 32000 done!
# 12000 out of 32000 done!
# 12100 out of 32000 done!
# 12200 out of 32000 done!
# 12300 out of 32000 done!
# 12400 out of 32000 done!
# 12500 out of 32000 done!
# 12600 out of 32000 done!
# 12700 out of 32000 done!
# 12800 out of 32000 done!
# 12900 out of 32000 done!
# 13000 out of 32000 done!
# 13100 out of 32000 done!
# 13200 out of 32000 done!
# 13300 out of 32000 done!
# 13400 out of 32000 done!
# 13500 out of 32000 done!
# 13600 out of 32000 done!
# 13700 out of 32000 done!
# 13800 out of 32000 done!
# 13900 out of 32000 done!
# 14000 out of 32000 done!
# 14100 out of 32000 done!
# 14200 out of 32000 done!
# 14300 out of 32000 done!
# 14400 out of 32000 done!
# 14500 out of 32000 done!
# 14600 out of 32000 done!
# 14700 out of 32000 done!
# 14800 out of 32000 done!
# 14900 out of 32000 done!
# 15000 out of 32000 done!
# 15100 out of 32000 done!
# 15200 out of 32000 done!
# 15300 out of 32000 done!
# 15400 out of 32000 done!
# 15500 out of 32000 done!
# 15600 out of 32000 done!
# 15700 out of 32000 done!
# 15800 out of 32000 done!
# 15900 out of 32000 done!
# 16000 out of 32000 done!
# 16100 out of 32000 done!
# 16200 out of 32000 done!
# 16300 out of 32000 done!
# 16400 out of 32000 done!
# 16500 out of 32000 done!
# 16600 out of 32000 done!
# 16700 out of 32000 done!
# 16800 out of 32000 done!
# 16900 out of 32000 done!
# 17000 out of 32000 done!
# 17100 out of 32000 done!
# 17200 out of 32000 done!
# 17300 out of 32000 done!
# 17400 out of 32000 done!
# 17500 out of 32000 done!
# 17600 out of 32000 done!
# 17700 out of 32000 done!
# 17800 out of 32000 done!
# 17900 out of 32000 done!
# 18000 out of 32000 done!
# 18100 out of 32000 done!
# 18200 out of 32000 done!
# 18300 out of 32000 done!
# 18400 out of 32000 done!
# 18500 out of 32000 done!
# 18600 out of 32000 done!
# 18700 out of 32000 done!
# 18800 out of 32000 done!
# 18900 out of 32000 done!
# 19000 out of 32000 done!
# 19100 out of 32000 done!
# 19200 out of 32000 done!
# 19300 out of 32000 done!
# 19400 out of 32000 done!
# 19500 out of 32000 done!
# 19600 out of 32000 done!
# 19700 out of 32000 done!
# 19800 out of 32000 done!
# 19900 out of 32000 done!
# 20000 out of 32000 done!
# 20100 out of 32000 done!
# 20200 out of 32000 done!
# 20300 out of 32000 done!
# 20400 out of 32000 done!
# 20500 out of 32000 done!
# 20600 out of 32000 done!
# 20700 out of 32000 done!
# 20800 out of 32000 done!
# 20900 out of 32000 done!
# 21000 out of 32000 done!
# 21100 out of 32000 done!
# 21200 out of 32000 done!
# 21300 out of 32000 done!
# 21400 out of 32000 done!
# 21500 out of 32000 done!
# 21600 out of 32000 done!
# 21700 out of 32000 done!
# 21800 out of 32000 done!
# 21900 out of 32000 done!
# 22000 out of 32000 done!
# 22100 out of 32000 done!
# 22200 out of 32000 done!
# 22300 out of 32000 done!
# 22400 out of 32000 done!
# 22500 out of 32000 done!
# 22600 out of 32000 done!
# 22700 out of 32000 done!
# 22800 out of 32000 done!
# 22900 out of 32000 done!
# 23000 out of 32000 done!
# 23100 out of 32000 done!
# 23200 out of 32000 done!
# 23300 out of 32000 done!
# 23400 out of 32000 done!
# 23500 out of 32000 done!
# 23600 out of 32000 done!
# 23700 out of 32000 done!
# 23800 out of 32000 done!
# 23900 out of 32000 done!
# 24000 out of 32000 done!
# 24100 out of 32000 done!
# 24200 out of 32000 done!
# 24300 out of 32000 done!
# 24400 out of 32000 done!
# 24500 out of 32000 done!
# 24600 out of 32000 done!
# 24700 out of 32000 done!
# 24800 out of 32000 done!
# 24900 out of 32000 done!
# 25000 out of 32000 done!
# 25100 out of 32000 done!
# 25200 out of 32000 done!
# 25300 out of 32000 done!
# 25400 out of 32000 done!
# 25500 out of 32000 done!
# 25600 out of 32000 done!
# 25700 out of 32000 done!
# 25800 out of 32000 done!
# 25900 out of 32000 done!
# 26000 out of 32000 done!
# 26100 out of 32000 done!
# 26200 out of 32000 done!
# 26300 out of 32000 done!
# 26400 out of 32000 done!
# 26500 out of 32000 done!
# 26600 out of 32000 done!
# 26700 out of 32000 done!
# 26800 out of 32000 done!
# 26900 out of 32000 done!
# 27000 out of 32000 done!
# 27100 out of 32000 done!
# 27200 out of 32000 done!
# 27300 out of 32000 done!
# 27400 out of 32000 done!
# 27500 out of 32000 done!
# 27600 out of 32000 done!
# 27700 out of 32000 done!
# 27800 out of 32000 done!
# 27900 out of 32000 done!
# 28000 out of 32000 done!
# 28100 out of 32000 done!
# 28200 out of 32000 done!
# 28300 out of 32000 done!
# 28400 out of 32000 done!
# 28500 out of 32000 done!
# 28600 out of 32000 done!
# 28700 out of 32000 done!
# 28800 out of 32000 done!
# 28900 out of 32000 done!
# 29000 out of 32000 done!
# 29100 out of 32000 done!
# 29200 out of 32000 done!
# 29300 out of 32000 done!
# 29400 out of 32000 done!
# 29500 out of 32000 done!
# 29600 out of 32000 done!
# 29700 out of 32000 done!
# 29800 out of 32000 done!
# 29900 out of 32000 done!
# 30000 out of 32000 done!
# 30100 out of 32000 done!
# 30200 out of 32000 done!
# 30300 out of 32000 done!
# 30400 out of 32000 done!
# 30500 out of 32000 done!
# 30600 out of 32000 done!
# 30700 out of 32000 done!
# 30800 out of 32000 done!
# 30900 out of 32000 done!
# 31000 out of 32000 done!
# 31100 out of 32000 done!
# 31200 out of 32000 done!
# 31300 out of 32000 done!
# 31400 out of 32000 done!
# 31500 out of 32000 done!
# 31600 out of 32000 done!
# 31700 out of 32000 done!
# 31800 out of 32000 done!
# 31900 out of 32000 done!
# 32000 out of 32000 done!

# %%
output_cv = pd.DataFrame({'idx':np.array(idx_all),
                          'solv1_x':np.array(solv1_x_all),
                          'solv2_x':np.array(solv2_x_all),
                          'true_gam1':np.array(true_gam1_all),
                          'pred_gam1':np.array(pred_gam1_all),
                          'true_gam2':np.array(true_gam2_all),
                          'pred_gam2':np.array(pred_gam2_all),
                          'true_gam3':np.array(true_gam3_all),
                          'pred_gam3':np.array(pred_gam3_all),
                          'intra_hb1':np.array(intra_hb1_all),
                          'intra_hb2':np.array(intra_hb2_all),
                          'intra_hb3':np.array(intra_hb3_all),
                          'inter_hb12':np.array(inter_hb12_all),
                          'inter_hb13':np.array(inter_hb13_all),
                          'inter_hb23':np.array(inter_hb23_all)                 
                          })
output_cv.to_csv(saved_model_dir + 'analysis/output_cv.csv',index=False)

# %%
import pandas as pd
import numpy as np
import matplotlib
xmin = -21
xmax = 8
output_cv = pd.read_csv('../analysis/output_cv.csv')
output_cv = output_cv.sort_values(by="tpsa_binary_avg",ascending=False)
color_list = matplotlib.cm.get_cmap('tab10')
labels = ["nonpolar-nonpolar-nonpolar","polar-nonpolar-nonpolar","polar-polar-nonpolar","polar-polar-polar"]
fig,ax = plt.subplots(1,3,figsize=(9,3))
ax[0].grid(color='lightgray',linewidth=0.75,alpha=0.5)
ax[1].grid(color='lightgray',linewidth=0.75,alpha=0.5)
ax[2].grid(color='lightgray',linewidth=0.75,alpha=0.5)
ax[0].plot([xmin, xmax], 
           [xmin, xmax], color='black',linestyle='--', lw=1)
ax[1].plot([xmin, xmax], 
           [xmin, xmax], color='black',linestyle='--', lw=1)
ax[2].plot([xmin, xmax], 
           [xmin, xmax], color='black',linestyle='--', lw=1)
ax[0].scatter(output_cv['true_gam1'],output_cv['pred_gam1'],c=color_list(output_cv['tpsa_binary_avg']),s=6,alpha=0.7)
ax[1].scatter(output_cv['true_gam2'],output_cv['pred_gam2'],c=color_list(output_cv['tpsa_binary_avg']),s=6,alpha=0.7)
ax[2].scatter(output_cv['true_gam3'],output_cv['pred_gam3'],c=color_list(output_cv['tpsa_binary_avg']),s=6,alpha=0.7)

ax[0].set_xlabel('True $\ln\gamma_1$')
ax[0].set_ylabel('Predicted $\ln\gamma_1$')
ax[0].set_title('$R^2$={:.2f},MAE={:.3f},RMSE={:.3f}'.format(r2_score(output_cv['true_gam1'],output_cv['pred_gam1']),
                                                  mean_absolute_error(output_cv['true_gam1'],output_cv['pred_gam1']),
                                                  np.sqrt(mean_squared_error(output_cv['true_gam1'],output_cv['pred_gam1']))))

ax[1].set_xlabel('True $\ln\gamma_2$')
ax[1].set_ylabel('Predicted $\ln\gamma_2$')

ax[1].set_title('$R^2$={:.2f},MAE={:.3f},RMSE={:.3f}'.format(r2_score(output_cv['true_gam2'],output_cv['pred_gam2']),
                                                  mean_absolute_error(output_cv['true_gam2'],output_cv['pred_gam2']),
                                                  np.sqrt(mean_squared_error(output_cv['true_gam2'],output_cv['pred_gam2']))))
ax[2].set_xlabel('True $\ln\gamma_3$')
ax[2].set_ylabel('Predicted $\ln\gamma_3$')

ax[2].set_title('$R^2$={:.2f},MAE={:.3f},RMSE={:.3f}'.format(r2_score(output_cv['true_gam3'],output_cv['pred_gam3']),
                                                  mean_absolute_error(output_cv['true_gam3'],output_cv['pred_gam3']),
                                                  np.sqrt(mean_squared_error(output_cv['true_gam3'],output_cv['pred_gam3']))))
for i in range(3):
    ax[i].set_xticks(np.arange(-20,6,5))
plt.tight_layout()
plt.show()
plt.savefig('../analysis/cv_parity_color.png',pad_inches=0,dpi=400,transparent=True)   
plt.close()
