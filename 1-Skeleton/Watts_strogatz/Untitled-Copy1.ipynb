# %%
import networkx as nx
import numpy as np
import scipy 
from scipy.sparse import csr_matrix
from scipy.sparse.csgraph import connected_components
import matplotlib.pyplot as plt
import scipy.optimize as optim
import pysal
from matplotlib.ticker import FormatStrFormatter
from matplotlib.ticker import StrMethodFormatter
import matplotlib
import seaborn as sns
from tqdm import tqdm
sns.set()
sns.set_context("talk", font_scale = 1.5)
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'
matplotlib.rcParams['font.size'] = 20
matplotlib.rcParams['axes.axisbelow'] = True
#matplotlib.rcParams.update({'figure.autolayout': True})
matplotlib.rcParams['figure.figsize'] = [10, 7]
# Out:
# C:\Users\Alex\Anaconda3\lib\site-packages\pysal\lib\weights\util.py:19: UserWarning: geopandas not available. Some functionality will be disabled.
#   warn('geopandas not available. Some functionality will be disabled.')
# C:\Users\Alex\Anaconda3\lib\site-packages\pysal\model\spvcm\abstracts.py:10: UserWarning: The `dill` module is required to use the sqlite backend fully.
#   from .sqlite import head_to_sql, start_sql

# %%
G = nx.generators.random_graphs.connected_watts_strogatz_graph(100,4,.5)
A = nx.convert_matrix.to_numpy_array(G)

# %%
plt.imshow(A)

# %%
def euler_char(A,G):
    Betti1 = []
    edge = []
    vert = []
    com = []
    As = []
    Ms = []
    
    thresh = np.linspace(0,1,40)
    
    Mat = nx.convert_matrix.to_numpy_array(G)
    
    for t in thresh:
        
        M = np.array(Mat)
        
        #Binary Image
#         A = (A - A.min())/(A.max() - A.min())
        binary = (A <= t)*1
        #Adjust Adjaceny Matrix
        count = 0
        for i in range(len(A)):
            if binary[i] == 0:
                M[count,:] = 0
                M[:,count] = 0
            count += 1

        #Number Edges
        Edges = np.sum(M)/2
        
        #Number Vertices
        Vertices = np.sum(binary)
        
        removed_Vertices = np.shape(M)[0] - Vertices
        
        #Number Connected Components
        graph = csr_matrix(M)
        n_comp = connected_components(csgraph = graph, directed = False, return_labels = False)
        n_comp = n_comp - removed_Vertices
        
        #Betti 1
        B1 = n_comp - Vertices + Edges
        
        Betti1.append(B1)
        
        edge.append(Edges)
        
        vert.append(Vertices)
        
        com.append(n_comp)
        
        As.append(binary)
        
        Ms.append(M)
        
    return Betti1

# %%
betti1s = []
C = []
for i in range(100):
    A = np.absolute(np.random.normal(.3,.2,300))
    G = nx.generators.random_graphs.connected_watts_strogatz_graph(300,10,.9)
    a = np.stack(euler_char(A,G))
    betti1s.append(a)
    C.append(nx.algorithms.cluster.average_clustering(G))

# %%
betti1z = np.vstack(betti1s)
C1z = np.stack(C)

# %%
plt.plot(betti1z.T)
# Out:
# [<matplotlib.lines.Line2D at 0x176eee10>,
#  <matplotlib.lines.Line2D at 0x176eef98>,
#  <matplotlib.lines.Line2D at 0x178b7160>,
#  <matplotlib.lines.Line2D at 0x178b72e8>,
#  <matplotlib.lines.Line2D at 0x178b7470>,
#  <matplotlib.lines.Line2D at 0x178b75f8>,
#  <matplotlib.lines.Line2D at 0x178b7780>,
#  <matplotlib.lines.Line2D at 0x178b7908>,
#  <matplotlib.lines.Line2D at 0x178b7a90>,
#  <matplotlib.lines.Line2D at 0x178b7c18>,
#  <matplotlib.lines.Line2D at 0x17878e10>,
#  <matplotlib.lines.Line2D at 0x178b7ef0>,
#  <matplotlib.lines.Line2D at 0x1788f0b8>,
#  <matplotlib.lines.Line2D at 0x1788f240>,
#  <matplotlib.lines.Line2D at 0x1788f3c8>,
#  <matplotlib.lines.Line2D at 0x1788f550>,
#  <matplotlib.lines.Line2D at 0x1788f6d8>,
#  <matplotlib.lines.Line2D at 0x1788f860>,
#  <matplotlib.lines.Line2D at 0x1788f9e8>,
#  <matplotlib.lines.Line2D at 0x1788fb70>,
#  <matplotlib.lines.Line2D at 0x1788fcf8>,
#  <matplotlib.lines.Line2D at 0x1788fe80>,
#  <matplotlib.lines.Line2D at 0x178b8048>,
#  <matplotlib.lines.Line2D at 0x178b81d0>,
#  <matplotlib.lines.Line2D at 0x178b8358>,
#  <matplotlib.lines.Line2D at 0x178b84e0>,
#  <matplotlib.lines.Line2D at 0x178b8668>,
#  <matplotlib.lines.Line2D at 0x178b87f0>,
#  <matplotlib.lines.Line2D at 0x178b8978>,
#  <matplotlib.lines.Line2D at 0x178b8b00>,
#  <matplotlib.lines.Line2D at 0x178b8c88>,
#  <matplotlib.lines.Line2D at 0x178b8e10>,
#  <matplotlib.lines.Line2D at 0x178b8f98>,
#  <matplotlib.lines.Line2D at 0x178a4160>,
#  <matplotlib.lines.Line2D at 0x178a42e8>,
#  <matplotlib.lines.Line2D at 0x178a4470>,
#  <matplotlib.lines.Line2D at 0x178a45f8>,
#  <matplotlib.lines.Line2D at 0x178a4780>,
#  <matplotlib.lines.Line2D at 0x178a4908>,
#  <matplotlib.lines.Line2D at 0x178a4a90>,
#  <matplotlib.lines.Line2D at 0x178a4c18>,
#  <matplotlib.lines.Line2D at 0x178a4da0>,
#  <matplotlib.lines.Line2D at 0x178a4f28>,
#  <matplotlib.lines.Line2D at 0x178ab0f0>,
#  <matplotlib.lines.Line2D at 0x178ab278>,
#  <matplotlib.lines.Line2D at 0x178ab400>,
#  <matplotlib.lines.Line2D at 0x178ab588>,
#  <matplotlib.lines.Line2D at 0x178ab710>,
#  <matplotlib.lines.Line2D at 0x178ab898>,
#  <matplotlib.lines.Line2D at 0x178aba20>,
#  <matplotlib.lines.Line2D at 0x178abba8>,
#  <matplotlib.lines.Line2D at 0x178abd30>,
#  <matplotlib.lines.Line2D at 0x178abeb8>,
#  <matplotlib.lines.Line2D at 0x178bc080>,
#  <matplotlib.lines.Line2D at 0x178bc208>,
#  <matplotlib.lines.Line2D at 0x178bc390>,
#  <matplotlib.lines.Line2D at 0x178bc518>,
#  <matplotlib.lines.Line2D at 0x178bc6a0>,
#  <matplotlib.lines.Line2D at 0x178bc828>,
#  <matplotlib.lines.Line2D at 0x178bc9b0>,
#  <matplotlib.lines.Line2D at 0x178bcb38>,
#  <matplotlib.lines.Line2D at 0x178bccc0>,
#  <matplotlib.lines.Line2D at 0x178bce48>,
#  <matplotlib.lines.Line2D at 0x178bcfd0>,
#  <matplotlib.lines.Line2D at 0x1788c198>,
#  <matplotlib.lines.Line2D at 0x1788c320>,
#  <matplotlib.lines.Line2D at 0x1788c4a8>,
#  <matplotlib.lines.Line2D at 0x1788c630>,
#  <matplotlib.lines.Line2D at 0x1788c7b8>,
#  <matplotlib.lines.Line2D at 0x1788c940>,
#  <matplotlib.lines.Line2D at 0x1788cac8>,
#  <matplotlib.lines.Line2D at 0x1788cc50>,
#  <matplotlib.lines.Line2D at 0x1788cdd8>,
#  <matplotlib.lines.Line2D at 0x1788cf60>,
#  <matplotlib.lines.Line2D at 0x178b3128>,
#  <matplotlib.lines.Line2D at 0x178b32b0>,
#  <matplotlib.lines.Line2D at 0x178b3438>,
#  <matplotlib.lines.Line2D at 0x178b35c0>,
#  <matplotlib.lines.Line2D at 0x178b3748>,
#  <matplotlib.lines.Line2D at 0x178b38d0>,
#  <matplotlib.lines.Line2D at 0x178b3a58>,
#  <matplotlib.lines.Line2D at 0x178b3be0>,
#  <matplotlib.lines.Line2D at 0x178b3d68>,
#  <matplotlib.lines.Line2D at 0x178b3ef0>,
#  <matplotlib.lines.Line2D at 0x177260b8>,
#  <matplotlib.lines.Line2D at 0x17726240>,
#  <matplotlib.lines.Line2D at 0x177263c8>,
#  <matplotlib.lines.Line2D at 0x17726550>,
#  <matplotlib.lines.Line2D at 0x177266d8>,
#  <matplotlib.lines.Line2D at 0x17726860>,
#  <matplotlib.lines.Line2D at 0x177269e8>,
#  <matplotlib.lines.Line2D at 0x17726b70>,
#  <matplotlib.lines.Line2D at 0x17726cf8>,
#  <matplotlib.lines.Line2D at 0x17726e80>,
#  <matplotlib.lines.Line2D at 0x17733048>,
#  <matplotlib.lines.Line2D at 0x177331d0>,
#  <matplotlib.lines.Line2D at 0x17733358>,
#  <matplotlib.lines.Line2D at 0x177334e0>,
#  <matplotlib.lines.Line2D at 0x17733668>,
#  <matplotlib.lines.Line2D at 0x177337f0>]

# %%
betti2s = []
C = []
for i in range(100):
    A = np.absolute(np.random.normal(.3,.2,300))
    G = nx.generators.random_graphs.connected_watts_strogatz_graph(300,10,.1)
    a = np.stack(euler_char(A,G))
    betti2s.append(a)
    C.append(nx.algorithms.cluster.average_clustering(G))

# %%
betti2z = np.vstack(betti2s)
C2z = np.stack(C)

# %%
plt.plot(betti1z.T,'r')
plt.plot(betti2z.T,'b')
plt.ylabel(r"$\beta_1$")
plt.xlabel("filtration level")

# %%
plt.plot(C2z)
plt.plot(C1z)

# %%
import scipy.optimize as optim
p0 = np.random.exponential(size = 3)
bounds = (0,[100000,100,2000000])

def logistic(t,a,b,c):
    return c/(1+a*np.exp(-b*t))

def fit_log(Data,thresh):
#     params = []
#     for i in range(len(Data)):
    p0 = np.random.exponential(size = 3)
    bounds = (0,[1000,500,3000])
    x = thresh
#         y = (Data[i] - Data[i].min())/(Data[i].max() - Data[i].min())
    y = Data
    (a,b,c),cov = optim.curve_fit(logistic,x,y,bounds = bounds, p0=p0)
    param = [a,b,c]
#         params.append(param)
    return param

# %%
thresh = np.linspace(.01,1,40)
yeahboy = np.linspace(0,1,10)

AllCz = []
AllBettiz = []
paramz = []
lengthz = []
for j in tqdm(yeahboy):
    C = []
    params = []
    length = []
    for i in range(10):
        A = np.random.rand(300)
        G = nx.generators.random_graphs.connected_watts_strogatz_graph(300,10,j)
        a = np.stack(euler_char(A,G))
        param = fit_log(a,thresh)
        C.append(nx.algorithms.cluster.average_clustering(G))
        params.append(np.stack(param))
        length.append(nx.average_shortest_path_length(G))
    
    lengthz.append(length)
    paramz.append(params)
    AllCz.append(np.stack(C))
# Out:
# 100%|██████████████████████████████████████████| 10/10 [00:48<00:00,  4.86s/it]

# %%
paramzz = np.asarray(paramz)

# %%
plt.plot(paramzz[1,:,1],'o')
plt.plot(paramzz[0,:,1],'o')
plt.plot(paramzz[2,:,1],'o')
plt.plot(paramzz[3,:,1],'o')
plt.plot(paramzz[7,:,1],'o')

# %%
plt.plot(np.asarray(AllCz).T)
# Out:
# [<matplotlib.lines.Line2D at 0x13677d68>,
#  <matplotlib.lines.Line2D at 0x13677ef0>,
#  <matplotlib.lines.Line2D at 0x136600b8>,
#  <matplotlib.lines.Line2D at 0x13660240>,
#  <matplotlib.lines.Line2D at 0x136603c8>,
#  <matplotlib.lines.Line2D at 0x13660550>,
#  <matplotlib.lines.Line2D at 0x136606d8>,
#  <matplotlib.lines.Line2D at 0x13660860>,
#  <matplotlib.lines.Line2D at 0x136609e8>,
#  <matplotlib.lines.Line2D at 0x13660b70>]

# %%
data = np.mean(paramzz[:,:,0],axis = 1)
data1 = np.mean(paramzz[:,:,1],axis = 1)
data2 = np.mean(paramzz[:,:,2],axis = 1)
data3 = np.mean(np.asarray(AllCz),axis = 1)
data4 = np.mean(np.asarray(lengthz),axis = 1)

# %%
# plt.plot(data)
# plt.plot(data2)
plt.plot(data2[1::],'o')

# %%
plt.plot(yeahboy,data2,'o')

# %%
plt.plot(yeahboy,data,'o')
plt.ylabel(r"Mean $\beta_1$ Maximal Growth Value")
plt.xlabel("Watts-Strogatz $p$ Value")
# Out:
# Text(0.5, 0, 'Watts-Strogatz $p$ Value')

# %%
plt.plot(yeahboy,data1,'o')
plt.ylabel(r"Mean $\beta_1$ Maximal Growth Value")
plt.xlabel("Watts-Strogatz $p$ Value")
# Out:
# Text(0.5, 0, 'Watts-Strogatz $p$ Value')

# %%
plt.plot(length)

# %%
np.random.rand(100)
