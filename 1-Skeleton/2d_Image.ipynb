# %%
import numpy as np
import scipy 
from scipy.sparse import csr_matrix
from scipy.sparse.csgraph import connected_components
import matplotlib.pyplot as plt
import scipy.optimize as optim
import pysal
from matplotlib.ticker import FormatStrFormatter
from matplotlib.ticker import StrMethodFormatter
import matplotlib
import seaborn as sns
sns.set()
sns.set_context("talk", font_scale = 1.5)
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'
matplotlib.rcParams['font.size'] = 20
matplotlib.rcParams['axes.axisbelow'] = True
#matplotlib.rcParams.update({'figure.autolayout': True})
matplotlib.rcParams['figure.figsize'] = [10, 7]
# Out:
# C:\Users\Alex\Anaconda3\lib\site-packages\pysal\lib\weights\util.py:19: UserWarning: geopandas not available. Some functionality will be disabled.
#   warn('geopandas not available. Some functionality will be disabled.')
# C:\Users\Alex\Anaconda3\lib\site-packages\pysal\model\spvcm\abstracts.py:10: UserWarning: The `dill` module is required to use the sqlite backend fully.
#   from .sqlite import head_to_sql, start_sql

# %%
def make_matrix(rows, cols):
    n = rows*cols
    M = np.zeros((n,n))
    for r in range(rows):
        for c in range(cols):
            i = r*cols + c
            # Two inner diagonals
            if c > 0: M[i-1,i] = M[i,i-1] = 1
            # Two outer diagonals
            if r > 0: M[i-cols,i] = M[i,i-cols] = 1
                
    return M

# %%
def euler_char(A,dim1,dim2,thresh):
    Betti1 = []
    edge = []
    vert = []
    com = []
    As = []
    Ms = []
    for t in thresh:
        
        M = make_matrix(dim1,dim2)
        
        #Binary Image
        binary = (A <= t)*1
        #Adjust Adjaceny Matrix
        count = 0
        for i in range(np.shape(A)[1]):
            for j in range(np.shape(A)[0]):
                if binary[j,i] == 0:
                    M[count,:] = 0
                    M[:,count] = 0
                count += 1
                
        #Number Edges
        Edges = np.sum(M)/2
        
        #Number Vertices
        Vertices = np.sum(binary)
        
        removed_Vertices = np.shape(M)[0] - Vertices
        
        #Number Connected Components
        graph = csr_matrix(M)
        n_comp = connected_components(csgraph = graph, directed = False, return_labels = False)
        n_comp = n_comp - removed_Vertices
        
        #Betti 1
        B1 = n_comp - Vertices + Edges
        
        Betti1.append(B1)
        
        edge.append(Edges)
        
        vert.append(Vertices)
        
        com.append(n_comp)
        
        As.append(binary)
        
        Ms.append(M)
        
    return Betti1

# %%
U = 30
m = np.linspace(-1, 1, U)    # 60 points between -1 and 1
delta = m[1] - m[0]              # delta^2 is the area of each grid cell
(x, y) = np.meshgrid(m, m)       # Create the mesh

M = make_matrix(30,30)
thresh = np.arange(0.05,1,.05)


# Create the matrix of weigthts
w = pysal.lib.weights.lat2W(M.shape[0], M.shape[1])




def logistic(t,a,b,c):
    return c/(1+a*np.exp(-b*t))

def data_col(sigma,numgauss,points):
    allker = []
    ker = 0
    for j in range(points):
        for i in range(numgauss):
            k = np.random.uniform(-1,1,1)
            j = np.random.uniform(-1,1,1)
            norm_constant = 1 / (2 * np.pi * sigma**2)
            rhs = np.exp(-.5 * ((x + j)**2 + (y + k)**2) / sigma**2)
            kers = norm_constant * rhs
            ker = kers + ker
        ker = (ker - np.min(ker))/(np.max(ker) - np.min(ker))
        allker.append(ker)
        
    return allker

def fit_param(Data,M,thresh):
    X = np.vstack([np.ones(len(thresh)),thresh,thresh**2,thresh**3,thresh**4]).T
    psuedo = np.linalg.inv(X.T@X)@X.T
    params = []
    grads = []
    ys = []
    for i in range(len(Data)):
        M = make_matrix(U,U)
        y = np.vstack(euler_char(Data[i],U,U,thresh))
        param = psuedo@y
        params.append(param)
        grad = param[1] + param[2]*2*thresh + param[3]*thresh**2
        grads.append(np.max(grad))
        ys.append(y)
    return params,grads,ys

def fit_param_leg(Data,M,thresh):
    x = thresh
    params = []
    y = []
    for i in range(len(Data)):
        M = make_matrix(U,U)
        y = np.vstack(euler_char(Data[i],U,U,thresh))
        param = np.polynomial.legendre.legfit(thresh,y,4)
        params.append(param)
        ys.append(y)
    return params,ys

def fit_log(Data,M,thresh,w):
    x = thresh
    params = []
    ys = []
    Moran = []
    for i in range(len(Data)):
        M = make_matrix(U,U)
        w = pysal.lib.weights.lat2W(Data[i].shape[0], Data[i].shape[1])
        mi = pysal.explore.esda.moran.Moran(Data[i], w)
#         Data[i] = np.absolute(1 - Data[i])
        y = np.vstack(euler_char(Data[i],U,U,thresh))
        p0 = np.random.exponential(size = 3)
        bounds = (0,[1000000000,30,20000])
        x = thresh
        y = np.array(np.hstack(y))
#         y = (y - y.min())/(y.max() - y.min())
        (a,b,c),cov = optim.curve_fit(logistic,x,y,bounds = bounds, p0=p0)
        param = [a,b,c]
        params.append(param)
        ys.append(y)
        Moran.append(mi.I)
    return params,ys,Moran

# %%
Data1 = data_col(0.05,400,300)
Data2 = data_col(.05,200,300)

# %%
Param1,y1,Moran1 = fit_log(Data1,M,thresh,w)
Param2,y2,Moran2 = fit_log(Data2,M,thresh,w)
np.shape(Param1)
# Out:
# (300, 3)

# %%
Param11 = np.vstack(Param1).T
print(np.shape(Param11))
# grad11 = np.hstack(grad1)
Param21 = np.vstack(Param2).T
print(np.shape(Param21))
# grad12 = np.hstack(grad2)
# Out:
# (3, 300)
# (3, 300)

# %%
from sklearn.decomposition import PCA

paramz = np.hstack([Param11,Param21])

pca = PCA()

X = pca.fit_transform(paramz.T)

label1 = np.zeros(300)
label2 = label1 + 1

labelz = np.hstack([label1,label2])

plt.scatter(X[:,0],X[:,1],c = labelz)

weight = pca.components_

print(weight)
# Out:
# [[ 0.9994586   0.02211309 -0.02436209]
#  [-0.02472912  0.0164788  -0.99955836]
#  [-0.02170187  0.99961966  0.01701672]]

# %%
sns.distplot(Param11[2,:], label = "Data1")
sns.distplot(Param21[2,:],label = "Data2")

plt.ylabel("Density")
plt.xlabel("Logistic function $a$ value")
plt.legend()

plt.savefig("logisticdist.pdf")

# %%
sns.distplot(Moran2,label = "Data1")
sns.distplot(Moran1,label = "Data2")

plt.ylabel("Density")
plt.xlabel("Moran's I")
plt.legend()

plt.savefig("MoransIdist.pdf")

# %%
# sns.set_style("whitegrid", {'axes.grid' : False})
plt.imshow(Data1[20])

plt.gca().set(yticks=[])
plt.gca().set(xticks=[])

plt.savefig("data1.eps")

plt.figure()
sns.distplot(Data1[20].flatten())

# %%
plt.imshow(Data2[70])
# sns.set_style("whitegrid", {'axes.grid' : False})

plt.gca().set(yticks=[])
plt.gca().set(xticks=[])

plt.savefig("data2.eps")

plt.figure()
sns.distplot(Data2[70].flatten())

# %%
def logistic(t,a,b,c):
    return c/(1+a*np.exp(-b*t))

# %%
p0 = np.random.exponential(size = 3)
bounds = (0,[100000,20,2000])

# %%
import scipy.optimize as optim
x = thresh 
y = np.array(np.hstack(y2[15]))

(a,b,c),cov = optim.curve_fit(logistic,x,y,bounds = bounds, p0=p0)

# %%
a,b,c
# Out:
# (19.66499211643926, 7.706662619223365, 823.831401343148)

# %%
def my_log(t):
    return c/(1+a*np.exp(-b*t))

plt.plot(thresh,y,'o',label = "Data")
plt.plot(thresh,logistic(x,a,b,c), label = "Logistic Model")
plt.ylabel(r"$\beta_1$")
plt.xlabel(r"$f(G)$")
plt.legend()
plt.savefig("logisticfit.pdf")

# %%
y1t = np.vstack(y1)
plt.plot(thresh,y2t.T,'b')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-0476f1ffbb1a> in <module>
#       1 y1t = np.vstack(y1)
# ----> 2 plt.plot(thresh,y2t.T,'b')
#       3
#
# NameError: name 'y2t' is not defined

# %%
y2t = np.vstack(y2)
plt.plot(thresh,y1t.T,label = "Data 1")
plt.plot(thresh,y2t.T,label = "Data 2")
plt.legend()

# %%
plt.close('all')

plt.plot(thresh,np.mean(y1t.T,axis = 1),'o',label = "Data 1 Average")
plt.plot(thresh,np.mean(y2t.T,axis = 1),'o',label = "Data 2 Average")

plt.xlabel("$f(G)$")
plt.ylabel(r"Average $\beta_1$")
plt.legend()

plt.savefig("beta1meansgauss.pdf")

# %%
import scipy.optimize as optim
x = thresh 
y = np.mean(y2t.T,axis = 1)

(a,b,c),cov = optim.curve_fit(logistic,x,y,bounds = bounds, p0=p0)

# %%
a,b,c

# %%
x = thresh 
y = np.mean(y1t.T,axis = 1)

(a,b,c),cov = optim.curve_fit(logistic,x,y,bounds = bounds, p0=p0)

# %%
a,b,c

# %%
A = np.random.normal(.3,.3,(30,30))

A = (A - A.min())/(A.max() - A.min())

sns.distplot(A.flatten())

# %%
plt.imshow(A)

# %%
U = 30
M = make_matrix(U,U)
y = np.vstack(euler_char(A,U,U,thresh))
p0 = np.random.exponential(size = 3)
bounds = (0,[1000000000,30,20000])
x = thresh
y = np.array(np.hstack(y))
y = (y - y.min())/(y.max() - y.min())
(a,b,c),cov = optim.curve_fit(logistic,x,y,bounds = bounds, p0=p0)
param = [a,b,c]

# %%
plt.plot(y)
plt.plot(np.mean(y2t.T,axis = 1))

# %%
dif = np.mean(y2t.T,axis = 1) - np.mean(y1t.T,axis = 1)
plt.plot(dif)

# %%
plt.imshow((Data1[197] <= .5)*1 - (Data1[197] <= .3)*1)

# %%
plt.imshow((Data2[278] <= .5)*1 - (Data2[278] <= .3)*1)

# %%
plt.imshow((Data2[278]))

# %%
plt.imshow((Data1[197]))

# %%
np.shape(Param11)

# %% [markdown]
# %matplotlib notebook
# from mpl_toolkits.mplot3d import Axes3D
#
# fig = plt.figure()
# ax = fig.add_subplot(111, projection='3d')
#
# ax.scatter(Param11[0,:],Param11[1,:],Param11[2,:])
# ax.scatter(Param21[0,:],Param21[1,:],Param21[2,:])
