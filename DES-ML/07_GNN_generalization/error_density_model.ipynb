# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'STIXGeneral'
plt.rcParams['font.size'] = 10
plt.rcParams['axes.axisbelow'] = True
plt.rcParams['figure.figsize'] = [7, 5]  # Largo, ancho  
plt.rcParams["text.usetex"] = False
import numpy as np
import pandas as pd
import seaborn as sns

# %%
data_df = pd.read_csv('errors models.csv')
color = plt.colormaps['viridis'].resampled(5)

#ax = sns.displot(data=data_df, x="Errors", hue = "Model",kde=True, palette=viridis(range(4)))  # pandas core dataframe and label or position 

sns.set_style("whitegrid", {'grid.linestyle': '--'})
#ax = sns.displot(data=data_df, x="Errors", hue="Model", stat='count' ,kde=True, height=4, aspect=.7, palette=color(range(4)).tolist() )  # Una sola plot
#ax.set(xlabel = r'${\Delta}ln(x_{CO_2}) $', ylabel = r'$ Percentage $', title = '')

#ax = sns.displot(data=data_df, x="Errors", hue="Model" , col="Model",kde=True, height=4, aspect=.7, palette=color(range(4)).tolist() )  # 4 plots
#ax.set(xlabel = r'${\Delta}ln(x_{CO_2}) $', ylabel = r'$ Density $', title = '')

#Edgar plot
ax = sns.ecdfplot(data=data_df, x="Errors", hue="Model" ,stat='percent' )
ax.set(xlabel = r'${\Delta}ln(x_{CO_2}) $', ylabel = r'$ Percentage $', title = '')
plt.show()
